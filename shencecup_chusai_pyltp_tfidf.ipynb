# %%
import pandas as pd
import numpy as np
import datetime
import math
from gensim import corpora, models
from pyltp import SentenceSplitter
import functools
import os
from pyltp import Segmentor
from pyltp import Postagger

# %%
all_docs_df = pd.read_csv('../../data/chusai/all_docs.txt', sep='\001', header=None)
all_docs_df.columns = ['id', 'title', 'text']
all_docs_df['title'] = all_docs_df['title'].astype(str)
all_docs_df['text'] = all_docs_df['text'].astype(str)
print(all_docs_df.info())
print(all_docs_df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108295 entries, 0 to 108294
# Data columns (total 3 columns):
# id       108295 non-null object
# title    108295 non-null object
# text     108295 non-null object
# dtypes: object(3)
# memory usage: 2.5+ MB
# None
#         id                title  \
# 0  D000001   林志颖老婆深夜敷面膜，睫毛太长好吓人
# 1  D000002   小s夸杨幂身材好，杨幂回复太精彩了！
# 2  D000003    年轻时的她风华绝代，现却无人送祝福
# 3  D000004   林心如屡曝霍建华私生活被怼蹭老公人气
# 4  D000005  曾是TVB颜值担当，近照曝光发现真老了
#
#                                                 text
# 0  早年林志颖带kimi上《爸爸去哪儿》的时候，当时遮遮掩掩的林志颖老婆低调探班，总让人觉得格外...
# 1  翩若惊鸿，婉若游龙。曹植形容洛神的这两句，实在太抽象，以至于始终寻不到承受对象。直到在《大军...
# 2  上个世纪香港影视界涌现出了不少高颜值女星，在《大话西游之月光宝盒》中饰演春三十娘和蜘蛛精的蓝...
# 3  霍建华林心如1905电影网讯近日，林心如在接受采访时爆料称老公霍建华会主动向女儿索吻，笑称他...
# 4  不知道有多少人是看TVB剧集长大的，小时候我每一天晚上都会守着电视看TVB剧集的。可以说对于...

# %%
train_doc_keyword_df = pd.read_csv('../../data/chusai/train_docs_keywords.txt', sep='\t', header=None)
train_doc_keyword_df.columns = ['id', 'keyword']
train_doc_keyword_df['keyword_list'] = train_doc_keyword_df['keyword'].map(lambda x: x.split(','))
print(train_doc_keyword_df.head(10))
# Out:
#         id            keyword           keyword_list
# 0  D012650         三生三世,凤九,东华         [三生三世, 凤九, 东华]
# 1  D047118              南宁,美食               [南宁, 美食]
# 2  D098970             凉菜,北京人              [凉菜, 北京人]
# 3  D092010          华为,P30pro           [华为, P30pro]
# 4  D103408             酒吧,世界杯              [酒吧, 世界杯]
# 5  D103809            烧烤,人生一串             [烧烤, 人生一串]
# 6  D003823         惠若琪,杨颖,奔跑吧         [惠若琪, 杨颖, 奔跑吧]
# 7  D023499  我与你的光年距离2,王以纶,许晓诺  [我与你的光年距离2, 王以纶, 许晓诺]
# 8  D063937          无人机,军用,美军          [无人机, 军用, 美军]
# 9  D059085           女兵,剪影,欧美           [女兵, 剪影, 欧美]

# %%
LTP_DATA_DIR = '../../ltp/ltp_data_v3.4.0/'  # ltp模型目录的路径
cws_model_path = os.path.join(LTP_DATA_DIR, 'cws.model')  # 分词模型路径，模型名称为`cws.model`
segmentor = Segmentor()  # 初始化实例
segmentor.load(cws_model_path)  # 加载模型

pos_model_path = os.path.join(LTP_DATA_DIR, 'pos.model')  # 词性标注模型路径，模型名称为`pos.model`
postagger = Postagger() # 初始化实例
postagger.load(pos_model_path)  # 加载模型

# %%
#停用词表加载方法
def get_stopword_list():
    #停用词表存储路径，每一行为一个词，按行读取进行加载
    #进行编码转换确保匹配准确率
    stop_word_path = '../stopword.txt'
    stop_word_list = [sw.replace('\n', '') for sw in open(stop_word_path).readlines()]
    return stop_word_list

#分词方法，调用ltp接口
def seg_to_list(sentence):
    words = segmentor.segment(sentence)  # 分词
    seg_list = list(words)
    return seg_list

#去除干扰词
def word_filter(seg_list, stopword_list):
    
    filter_list = []
    #根据pos参数选择是否词性过滤
    #不进行词性过滤，则将词性都标记为n，表示全部保留
    for seg in seg_list:
        #过滤高停用词表中的词，以及长度为<2的词
        if not seg in stopword_list and len(seg) > 1:
            filter_list.append(seg)
    
    return filter_list

def jieba_word_deal(sentence, stopword_list):
    #调用上面方式对数据集进行处理，处理后的每条数据仅保留非干扰词
    seg_list = seg_to_list(sentence)
    filter_list = word_filter(seg_list, stopword_list)
    return filter_list

stopword_list = get_stopword_list()
all_docs_df['title_list'] = all_docs_df['title'].map(lambda x : jieba_word_deal(x, stopword_list))
all_docs_df['text_list'] = all_docs_df['text'].map(lambda x : jieba_word_deal(x, stopword_list))
all_docs_df['title_text'] = all_docs_df['title'] + '。' + all_docs_df['text']
all_docs_df['title_text_list'] = all_docs_df['title_text'].map(lambda x : jieba_word_deal(x, stopword_list))
print(all_docs_df.head(10))
# Out:
#         id                   title  \
# 0  D000001      林志颖老婆深夜敷面膜，睫毛太长好吓人
# 1  D000002      小s夸杨幂身材好，杨幂回复太精彩了！
# 2  D000003       年轻时的她风华绝代，现却无人送祝福
# 3  D000004      林心如屡曝霍建华私生活被怼蹭老公人气
# 4  D000005     曾是TVB颜值担当，近照曝光发现真老了
# 5  D000006  16岁的范冰冰有多美？塞娅公主看一眼被惊艳到
# 6  D000007        一样的北京，不一样的周迅与周冬雨
# 7  D000008      张杰自嘲是废物，赞谢娜是新时代好女性
# 8  D000009    杨幂获杂志主编夸奖：大幂幂瘦了越来越漂亮
# 9  D000010       杨幂女扮男装现身新节目瞬间年轻十岁
#
#                                                 text  \
# 0  早年林志颖带kimi上《爸爸去哪儿》的时候，当时遮遮掩掩的林志颖老婆低调探班，总让人觉得格外...
# 1  翩若惊鸿，婉若游龙。曹植形容洛神的这两句，实在太抽象，以至于始终寻不到承受对象。直到在《大军...
# 2  上个世纪香港影视界涌现出了不少高颜值女星，在《大话西游之月光宝盒》中饰演春三十娘和蜘蛛精的蓝...
# 3  霍建华林心如1905电影网讯近日，林心如在接受采访时爆料称老公霍建华会主动向女儿索吻，笑称他...
# 4  不知道有多少人是看TVB剧集长大的，小时候我每一天晚上都会守着电视看TVB剧集的。可以说对于...
# 5  范冰冰，家喻户晓的人物了，在出演还珠格格之前已经亭亭玉立十分美丽，在一些影剧中饰演一些小角色...
# 6  不知道刘若英与陈可辛之间有怎样的交情。《后来的我们》首映请来了陈可辛，他看完后笑着说很羡慕刘...
# 7  本文是企鹅号"不八卦会死人"原创文章，独家发布企鹅号，未经允许，不得转载!最新一期《向往的生...
# 8  网易娱乐4月29日报道  4月29日，时尚主编张宇晒出一组与杨幂的自拍合影，并发文：“今天与...
# 9  杨幂前段时间录制的综艺节目《我是大侦探》在4月29日播出预告，杨幂穿着校服的模样，甜死人了！...
#
#                    title_list  \
# 0   [林志颖, 老婆, 深夜, 面膜, 睫毛, 吓人]
# 1           [夸杨幂, 身材, 回复, 精彩]
# 2              [年轻, 风华绝代, 祝福]
# 3   [林心, 霍建华, 生活, 怼蹭, 老公, 人气]
# 4   [TVB, 颜值, 担当, 近照, 曝光, 发现]
# 5        [16, 冰冰, 塞娅, 公主, 惊艳]
# 6               [北京, 周迅, 周冬雨]
# 7   [张杰, 自嘲, 废物, 赞谢娜, 时代, 女性]
# 8  [杂志, 主编, 夸奖, 大幂幂, 越来越, 漂亮]
# 9        [男装, 现身, 节目, 瞬间, 年轻]
#
#                                            text_list  \
# 0  [早年, 志颖, kimi, 爸爸, 当时, 遮遮掩掩, 志颖, 老婆, 低调, 探班, 觉...
# 1  [翩若, 惊鸿, 婉若, 游龙, 曹植, 形容, 洛神, 实在, 抽象, 始终, 承受, 对...
# 2  [世纪, 香港, 影视界, 涌现, 不少, 高颜值, 女星, 大话, 西游, 光宝盒, 饰演...
# 3  [霍建华, 心如, 1905, 电影, 网讯, 近日, 林心如, 接受, 采访, 爆料, 老...
# 4  [知道, TVB, 剧集, 长大, 小时候, 晚上, 电视, TVB, 剧集, 时期, TV...
# 5  [冰冰, 家喻户晓, 人物, 出演, 格格, 之前, 已经, 亭亭玉立, 十分, 美丽, 影...
# 6  [知道, 刘若英, 陈可辛, 之间, 交情, 后来, 首映, 陈可辛, 羡慕, 刘若英, 以...
# 7  [本文, 企鹅, 八卦会, 死人, 原创, 文章, 独家, 发布, 企鹅, 未经, 允许, ...
# 8  [网易, 娱乐, 4月, 29日, 报道,   , 4月, 29日, 时尚, 主编, 张宇,...
# 9  [前段, 时间, 录制, 综艺, 节目, 侦探, 4月, 29日, 播出, 预告, 校服, ...
#
#                                           title_text  \
# 0  林志颖老婆深夜敷面膜，睫毛太长好吓人。早年林志颖带kimi上《爸爸去哪儿》的时候，当时遮遮掩...
# 1  小s夸杨幂身材好，杨幂回复太精彩了！。翩若惊鸿，婉若游龙。曹植形容洛神的这两句，实在太抽象，...
# 2  年轻时的她风华绝代，现却无人送祝福。上个世纪香港影视界涌现出了不少高颜值女星，在《大话西游之...
# 3  林心如屡曝霍建华私生活被怼蹭老公人气。霍建华林心如1905电影网讯近日，林心如在接受采访时爆...
# 4  曾是TVB颜值担当，近照曝光发现真老了。不知道有多少人是看TVB剧集长大的，小时候我每一天晚...
# 5  16岁的范冰冰有多美？塞娅公主看一眼被惊艳到。范冰冰，家喻户晓的人物了，在出演还珠格格之前已...
# 6  一样的北京，不一样的周迅与周冬雨。不知道刘若英与陈可辛之间有怎样的交情。《后来的我们》首映请...
# 7  张杰自嘲是废物，赞谢娜是新时代好女性。本文是企鹅号"不八卦会死人"原创文章，独家发布企鹅号，...
# 8  杨幂获杂志主编夸奖：大幂幂瘦了越来越漂亮。网易娱乐4月29日报道  4月29日，时尚主编张宇...
# 9  杨幂女扮男装现身新节目瞬间年轻十岁。杨幂前段时间录制的综艺节目《我是大侦探》在4月29日播出...
#
#                                      title_text_list
# 0  [林志颖, 老婆, 深夜, 面膜, 睫毛, 吓人, 早年, 志颖, kimi, 爸爸, 当时...
# 1  [夸杨幂, 身材, 回复, 精彩, 。翩若, 惊鸿, 婉若, 游龙, 曹植, 形容, 洛神,...
# 2  [年轻, 风华绝代, 祝福, 世纪, 香港, 影视界, 涌现, 不少, 高颜值, 女星, 大...
# 3  [林心, 霍建华, 生活, 怼蹭, 老公, 人气, 霍建华, 心如, 1905, 电影, 网...
# 4  [TVB, 颜值, 担当, 近照, 曝光, 发现, 知道, TVB, 剧集, 长大, 小时候...
# 5  [16, 冰冰, 塞娅, 公主, 惊艳, 冰冰, 家喻户晓, 人物, 出演, 格格, 之前,...
# 6  [北京, 周迅, 周冬雨, 知道, 刘若英, 陈可辛, 之间, 交情, 后来, 首映, 陈可...
# 7  [张杰, 自嘲, 废物, 赞谢娜, 时代, 女性, 本文, 企鹅, 八卦会, 死人, 原创,...
# 8  [杂志, 主编, 夸奖, 大幂幂, 越来越, 漂亮, 网易, 娱乐, 4月, 29日, 报道...
# 9  [男装, 现身, 节目, 瞬间, 年轻, 杨幂, 前段, 时间, 录制, 综艺, 节目, 侦...

# %%
all_docs_df['title_word_attributes'] = all_docs_df['title_list'].map(lambda x: list(postagger.postag(x)))
print(all_docs_df.head())
# Out:
#         id                title  \
# 0  D000001   林志颖老婆深夜敷面膜，睫毛太长好吓人
# 1  D000002   小s夸杨幂身材好，杨幂回复太精彩了！
# 2  D000003    年轻时的她风华绝代，现却无人送祝福
# 3  D000004   林心如屡曝霍建华私生活被怼蹭老公人气
# 4  D000005  曾是TVB颜值担当，近照曝光发现真老了
#
#                                                 text  \
# 0  早年林志颖带kimi上《爸爸去哪儿》的时候，当时遮遮掩掩的林志颖老婆低调探班，总让人觉得格外...
# 1  翩若惊鸿，婉若游龙。曹植形容洛神的这两句，实在太抽象，以至于始终寻不到承受对象。直到在《大军...
# 2  上个世纪香港影视界涌现出了不少高颜值女星，在《大话西游之月光宝盒》中饰演春三十娘和蜘蛛精的蓝...
# 3  霍建华林心如1905电影网讯近日，林心如在接受采访时爆料称老公霍建华会主动向女儿索吻，笑称他...
# 4  不知道有多少人是看TVB剧集长大的，小时候我每一天晚上都会守着电视看TVB剧集的。可以说对于...
#
#                   title_list  \
# 0  [林志颖, 老婆, 深夜, 面膜, 睫毛, 吓人]
# 1          [夸杨幂, 身材, 回复, 精彩]
# 2             [年轻, 风华绝代, 祝福]
# 3  [林心, 霍建华, 生活, 怼蹭, 老公, 人气]
# 4  [TVB, 颜值, 担当, 近照, 曝光, 发现]
#
#                                            text_list  \
# 0  [早年, 志颖, kimi, 爸爸, 当时, 遮遮掩掩, 志颖, 老婆, 低调, 探班, 觉...
# 1  [翩若, 惊鸿, 婉若, 游龙, 曹植, 形容, 洛神, 实在, 抽象, 始终, 承受, 对...
# 2  [世纪, 香港, 影视界, 涌现, 不少, 高颜值, 女星, 大话, 西游, 光宝盒, 饰演...
# 3  [霍建华, 心如, 1905, 电影, 网讯, 近日, 林心如, 接受, 采访, 爆料, 老...
# 4  [知道, TVB, 剧集, 长大, 小时候, 晚上, 电视, TVB, 剧集, 时期, TV...
#
#                                           title_text  \
# 0  林志颖老婆深夜敷面膜，睫毛太长好吓人。早年林志颖带kimi上《爸爸去哪儿》的时候，当时遮遮掩...
# 1  小s夸杨幂身材好，杨幂回复太精彩了！。翩若惊鸿，婉若游龙。曹植形容洛神的这两句，实在太抽象，...
# 2  年轻时的她风华绝代，现却无人送祝福。上个世纪香港影视界涌现出了不少高颜值女星，在《大话西游之...
# 3  林心如屡曝霍建华私生活被怼蹭老公人气。霍建华林心如1905电影网讯近日，林心如在接受采访时爆...
# 4  曾是TVB颜值担当，近照曝光发现真老了。不知道有多少人是看TVB剧集长大的，小时候我每一天晚...
#
#                                      title_text_list  \
# 0  [林志颖, 老婆, 深夜, 面膜, 睫毛, 吓人, 早年, 志颖, kimi, 爸爸, 当时...
# 1  [夸杨幂, 身材, 回复, 精彩, 。翩若, 惊鸿, 婉若, 游龙, 曹植, 形容, 洛神,...
# 2  [年轻, 风华绝代, 祝福, 世纪, 香港, 影视界, 涌现, 不少, 高颜值, 女星, 大...
# 3  [林心, 霍建华, 生活, 怼蹭, 老公, 人气, 霍建华, 心如, 1905, 电影, 网...
# 4  [TVB, 颜值, 担当, 近照, 曝光, 发现, 知道, TVB, 剧集, 长大, 小时候...
#
#                                          result_dict title_word_attributes
# 0  {'陈若仪': 0.42043875007548426, '睫毛': 0.126762024...  [nh, n, nt, n, n, a]
# 1  {'洛神': 0.3089820469477368, '张钧甯': 0.2172754939...          [v, n, v, a]
# 2  {'蓝洁瑛': 0.6918540227764125, '生日': 0.1292081837...             [a, i, v]
# 3  {'霍建华': 0.7722662755178248, '林心': 0.4401862939...  [nh, nh, v, v, n, n]
# 4  {'姚莹莹': 0.24113865228565598, 'TVB': 0.11166514...   [ws, n, v, n, v, v]

# %%
def get_title_person_name(title_list):
    attributes_list = list(postagger.postag(title_list))
    title_person_name_list = list()
    i = 0
    for attributes in attributes_list:
        if attributes == 'nh':
            title_person_name_list.append(title_list[i])
        i = i + 1
    return title_person_name_list

all_docs_df['title_person_name_list'] = all_docs_df['title_list'].map(lambda x: get_title_person_name(x))
print(all_docs_df[['title_list', 'title_person_name_list']].head(50))
# Out:
#                                      title_list     title_person_name_list
# 0                     [林志颖, 老婆, 深夜, 面膜, 睫毛, 吓人]                      [林志颖]
# 1                             [夸杨幂, 身材, 回复, 精彩]                         []
# 2                                [年轻, 风华绝代, 祝福]                         []
# 3                     [林心, 霍建华, 生活, 怼蹭, 老公, 人气]                  [林心, 霍建华]
# 4                     [TVB, 颜值, 担当, 近照, 曝光, 发现]                         []
# 5                          [16, 冰冰, 塞娅, 公主, 惊艳]                       [塞娅]
# 6                                 [北京, 周迅, 周冬雨]                  [周迅, 周冬雨]
# 7                     [张杰, 自嘲, 废物, 赞谢娜, 时代, 女性]                       [张杰]
# 8                    [杂志, 主编, 夸奖, 大幂幂, 越来越, 漂亮]                         []
# 9                          [男装, 现身, 节目, 瞬间, 年轻]                         []
# 10                     [搭戏, 彦祖, 出名, 如今, 40, 迎来]                         []
# 11                   [尴尬, 灏明, 音乐节, 卫生间, 突然, 拉开]                         []
# 12                         [仙女, 本人, 43, 志玲, 花娇]                         []
# 13              [主持人, 霸屏, 哪般, 提升, 能力, 与时俱进, 关键]                         []
# 14                   [沈阳, 妻子, 外出, 散步, 沈春阳, 素颜长]                         []
# 15                                   [怼天怼地, 冠希]                       [冠希]
# 16               [张艺谋, 太太, 首度, 受访, 老谋子, 爱情, 故事]                      [张艺谋]
# 17        [中国, 国际, 超模, 排行榜, 出炉, 第一, 意料, 之中, 争议]                         []
# 18                   [出演, 三生, 如今, 片约, 不断, 销声匿迹]                         []
# 19               [漫威, 漫画, 发展史, 发行, 电影, 具有, 说服力]                         []
# 20                    [后来, 票房, 10亿, 华语, 影史, 导演]                         []
# 21            [虐狗, 神剧, 开播, 收视率, 轻松, 破亿, 郑凯, 原因]                       [郑凯]
# 22                    [撞衫, 可怕, 尴尬, 看看, 娱乐圈, 明星]                         []
# 23                    [回顾, 电视剧, 那年, 正圆, 结局, 虐心]                         []
# 24             [不要, 出名, 头脑, 娱乐, 名媛, 小斐, 谨慎, 前行]                       [小斐]
# 25                                         [种田]                         []
# 26                         [吐槽, 裙子, 大步, 走路, 吐槽]                         []
# 27                                     [战神, 爱情]                         []
# 28                 [张翰, 湖南, 卫视, 回忆, 演艺, 生涯, 感慨]                       [张翰]
# 29               [27, 谭松韵, 17, 娱乐圈, 第一, 元气, 女神]                      [谭松韵]
# 30  [地表, 应援团, 周杰伦, 刘嘉玲, 梁朝伟, 张家辉, 邱淑贞, 组团, 演唱会]  [周杰伦, 刘嘉玲, 梁朝伟, 张家辉, 邱淑贞]
# 31   [静安, 戏剧, 汇集, 外国, 名团, 立陶宛, 国宝级, 导演, 带来, 力作]                         []
# 32                  [后来, 方小晓, 扮演者, 周冬雨, 主演, 电影]                 [方小晓, 周冬雨]
# 33        [电影, 电视剧, 长大, 原来, 唐僧, 真的, 喜欢, 女儿, 国王]                       [唐僧]
# 34               [吴彦祖, 黎明, 奇隆, 颜值, 巅峰, 年代, 纯天然]                      [吴彦祖]
# 35                [娱乐圈, 明星, 女友, 鹿晗, 眼神, 宠溺, 网友]                       [鹿晗]
# 36                   [别离, 李小冉, 演绎, 契约, 婚姻, 轻喜剧]                      [李小冉]
# 37                         [冠希, 男人, 男人, 转变, 过程]                         []
# 38         [男星, 长发, 杀马特, 灏明, 玛丽苏, 易烊, 千玺颠覆, 形象]                  [灏明, 玛丽苏]
# 39                       [后来, 无病呻吟, 有点, 过时, 土气]                         []
# 40                             [好友, 手机, 不止, 秘密]                         []
# 41                         [张翰, 闹翻, 许久, 联系, 关系]                       [张翰]
# 42           [八九十, 年代, 明星, 韩国, 人人, 喜欢, 张国荣, 希望]                      [张国荣]
# 43             [生活, 真实, 超越, 电影, 后来, 没有, 告诉, 真理]                         []
# 44                       [飞机场, 女王, 周冬雨, 简单, 样子]                      [周冬雨]
# 45                [漫威, 复仇者, 联盟, 无限, 战争, 票房, 历史]                         []
# 46                    [周杰伦, 妈妈, 撞衫, 身后, 女人, 抢镜]                      [周杰伦]
# 47                [金星, 曝光, 男人味, 十足, 网友, 激素, 反差]                         []
# 48                                 [科技, 城墙, 夜空]                         []
# 49                     [叶佳, 金句, 合集, 情话, 剧超, 好看]                       [叶佳]

# %%
#idf统计方法
def train_idf(doc_list):
    idf_dic = {}
    #总文档数
    tt_count = len(doc_list)
    
    #每个词出现的文档数
    for doc in doc_list:
        for word in set(doc):
            idf_dic[word] = idf_dic.get(word, 0.0) + 1.0
    
    #按公式转换为idf值，分母加1进行平滑处理
    for k, v in idf_dic.items():
        idf_dic[k] = math.log(tt_count / (1.0 + v))
        
    #对于没有在字典中的词，默认其尽在一个文档中出现，得到默认idf值
    default_idf = math.log(tt_count / (1.0))
    return idf_dic, default_idf

#排序函数，用于topK关键词的按值排
def cmp(e1, e2):
    res = np.sign(e1[1] - e2[1])
    if res != 0:
        return res
    else:
        a = e1[0] + e2[0]
        b = e2[0] + e1[0]
        if a > b:
            return 1
        elif a == b:
            return 0
        else:
            return -1

# %%
#TF-IDF类
class TfIdf(object):
    #四个参数分别是：训练好的idf字典，默认idf值，处理后的待提取文本，关键词数量
    def __init__(self, idf_dic, default_idf, word_list, keyword_num):
        self.word_list = word_list
        self.idf_dic = idf_dic
        self.default_idf = default_idf
        self.tf_dic = self.get_tf_dic()
        self.keyword_num = keyword_num
    
    #统计tf值
    def get_tf_dic(self):
        tf_dic = {}
        for word in self.word_list:
            tf_dic[word] = tf_dic.get(word, 0.0) + 1.0
        
        tt_count = len(self.word_list)
        for k, v in tf_dic.items():
            tf_dic[k] = float(v) / tt_count
        
        return tf_dic
    
    #按公式计算tf-idf
    def get_tfidf(self):
        tfidf_dic = {}
        for word in self.word_list:
            idf = self.idf_dic.get(word, self.default_idf)
            tf = self.tf_dic.get(word, 0)
            
            tfidf = tf * idf
            tfidf_dic[word] = tfidf
        
        result_dict = {}
        for k, v in sorted(tfidf_dic.items(), key=functools.cmp_to_key(cmp), reverse=True)[:self.keyword_num]:
            result_dict[k] = result_dict.get(k, 0.0) + float(v)
        return result_dict

# %%
idf_dic, default_idf = train_idf(all_docs_df['title_text_list'])
keyword_num = 5
all_docs_df['result_dict'] = all_docs_df['title_text_list'].map(lambda x: TfIdf(idf_dic, default_idf, x, keyword_num).get_tfidf())
print(all_docs_df.head())
# Out:
#         id                title  \
# 0  D000001   林志颖老婆深夜敷面膜，睫毛太长好吓人
# 1  D000002   小s夸杨幂身材好，杨幂回复太精彩了！
# 2  D000003    年轻时的她风华绝代，现却无人送祝福
# 3  D000004   林心如屡曝霍建华私生活被怼蹭老公人气
# 4  D000005  曾是TVB颜值担当，近照曝光发现真老了
#
#                                                 text  \
# 0  早年林志颖带kimi上《爸爸去哪儿》的时候，当时遮遮掩掩的林志颖老婆低调探班，总让人觉得格外...
# 1  翩若惊鸿，婉若游龙。曹植形容洛神的这两句，实在太抽象，以至于始终寻不到承受对象。直到在《大军...
# 2  上个世纪香港影视界涌现出了不少高颜值女星，在《大话西游之月光宝盒》中饰演春三十娘和蜘蛛精的蓝...
# 3  霍建华林心如1905电影网讯近日，林心如在接受采访时爆料称老公霍建华会主动向女儿索吻，笑称他...
# 4  不知道有多少人是看TVB剧集长大的，小时候我每一天晚上都会守着电视看TVB剧集的。可以说对于...
#
#                   title_list  \
# 0  [林志颖, 老婆, 深夜, 面膜, 睫毛, 吓人]
# 1          [夸杨幂, 身材, 回复, 精彩]
# 2             [年轻, 风华绝代, 祝福]
# 3  [林心, 霍建华, 生活, 怼蹭, 老公, 人气]
# 4  [TVB, 颜值, 担当, 近照, 曝光, 发现]
#
#                                            text_list  \
# 0  [早年, 志颖, kimi, 爸爸, 当时, 遮遮掩掩, 志颖, 老婆, 低调, 探班, 觉...
# 1  [翩若, 惊鸿, 婉若, 游龙, 曹植, 形容, 洛神, 实在, 抽象, 始终, 承受, 对...
# 2  [世纪, 香港, 影视界, 涌现, 不少, 高颜值, 女星, 大话, 西游, 光宝盒, 饰演...
# 3  [霍建华, 心如, 1905, 电影, 网讯, 近日, 林心如, 接受, 采访, 爆料, 老...
# 4  [知道, TVB, 剧集, 长大, 小时候, 晚上, 电视, TVB, 剧集, 时期, TV...
#
#                                           title_text  \
# 0  林志颖老婆深夜敷面膜，睫毛太长好吓人。早年林志颖带kimi上《爸爸去哪儿》的时候，当时遮遮掩...
# 1  小s夸杨幂身材好，杨幂回复太精彩了！。翩若惊鸿，婉若游龙。曹植形容洛神的这两句，实在太抽象，...
# 2  年轻时的她风华绝代，现却无人送祝福。上个世纪香港影视界涌现出了不少高颜值女星，在《大话西游之...
# 3  林心如屡曝霍建华私生活被怼蹭老公人气。霍建华林心如1905电影网讯近日，林心如在接受采访时爆...
# 4  曾是TVB颜值担当，近照曝光发现真老了。不知道有多少人是看TVB剧集长大的，小时候我每一天晚...
#
#                                      title_text_list  \
# 0  [林志颖, 老婆, 深夜, 面膜, 睫毛, 吓人, 早年, 志颖, kimi, 爸爸, 当时...
# 1  [夸杨幂, 身材, 回复, 精彩, 。翩若, 惊鸿, 婉若, 游龙, 曹植, 形容, 洛神,...
# 2  [年轻, 风华绝代, 祝福, 世纪, 香港, 影视界, 涌现, 不少, 高颜值, 女星, 大...
# 3  [林心, 霍建华, 生活, 怼蹭, 老公, 人气, 霍建华, 心如, 1905, 电影, 网...
# 4  [TVB, 颜值, 担当, 近照, 曝光, 发现, 知道, TVB, 剧集, 长大, 小时候...
#
#                                          result_dict
# 0  {'陈若仪': 0.42043875007548426, '睫毛': 0.126762024...
# 1  {'洛神': 0.3089820469477368, '张钧甯': 0.2172754939...
# 2  {'蓝洁瑛': 0.6918540227764125, '生日': 0.1292081837...
# 3  {'霍建华': 0.7722662755178248, '林心': 0.4401862939...
# 4  {'姚莹莹': 0.24113865228565598, 'TVB': 0.11166514...

# %%
sample_df = pd.read_csv('../../result/chusai/sample.csv', encoding='ISO-8859-1')
print(len(sample_df))
sample_df = pd.merge(sample_df, all_docs_df, on='id', how='left')
print(sample_df.head())
# Out:
# 107295
#         id label1 label2                title  \
# 0  D000001     ÎÞ     ÎÞ   林志颖老婆深夜敷面膜，睫毛太长好吓人
# 1  D000002     ÎÞ     ÎÞ   小s夸杨幂身材好，杨幂回复太精彩了！
# 2  D000003     ÎÞ     ÎÞ    年轻时的她风华绝代，现却无人送祝福
# 3  D000004     ÎÞ     ÎÞ   林心如屡曝霍建华私生活被怼蹭老公人气
# 4  D000005     ÎÞ     ÎÞ  曾是TVB颜值担当，近照曝光发现真老了
#
#                                                 text  \
# 0  早年林志颖带kimi上《爸爸去哪儿》的时候，当时遮遮掩掩的林志颖老婆低调探班，总让人觉得格外...
# 1  翩若惊鸿，婉若游龙。曹植形容洛神的这两句，实在太抽象，以至于始终寻不到承受对象。直到在《大军...
# 2  上个世纪香港影视界涌现出了不少高颜值女星，在《大话西游之月光宝盒》中饰演春三十娘和蜘蛛精的蓝...
# 3  霍建华林心如1905电影网讯近日，林心如在接受采访时爆料称老公霍建华会主动向女儿索吻，笑称他...
# 4  不知道有多少人是看TVB剧集长大的，小时候我每一天晚上都会守着电视看TVB剧集的。可以说对于...
#
#                   title_list  \
# 0  [林志颖, 老婆, 深夜, 面膜, 睫毛, 吓人]
# 1          [夸杨幂, 身材, 回复, 精彩]
# 2             [年轻, 风华绝代, 祝福]
# 3  [林心, 霍建华, 生活, 怼蹭, 老公, 人气]
# 4  [TVB, 颜值, 担当, 近照, 曝光, 发现]
#
#                                            text_list  \
# 0  [早年, 志颖, kimi, 爸爸, 当时, 遮遮掩掩, 志颖, 老婆, 低调, 探班, 觉...
# 1  [翩若, 惊鸿, 婉若, 游龙, 曹植, 形容, 洛神, 实在, 抽象, 始终, 承受, 对...
# 2  [世纪, 香港, 影视界, 涌现, 不少, 高颜值, 女星, 大话, 西游, 光宝盒, 饰演...
# 3  [霍建华, 心如, 1905, 电影, 网讯, 近日, 林心如, 接受, 采访, 爆料, 老...
# 4  [知道, TVB, 剧集, 长大, 小时候, 晚上, 电视, TVB, 剧集, 时期, TV...
#
#                                           title_text  \
# 0  林志颖老婆深夜敷面膜，睫毛太长好吓人。早年林志颖带kimi上《爸爸去哪儿》的时候，当时遮遮掩...
# 1  小s夸杨幂身材好，杨幂回复太精彩了！。翩若惊鸿，婉若游龙。曹植形容洛神的这两句，实在太抽象，...
# 2  年轻时的她风华绝代，现却无人送祝福。上个世纪香港影视界涌现出了不少高颜值女星，在《大话西游之...
# 3  林心如屡曝霍建华私生活被怼蹭老公人气。霍建华林心如1905电影网讯近日，林心如在接受采访时爆...
# 4  曾是TVB颜值担当，近照曝光发现真老了。不知道有多少人是看TVB剧集长大的，小时候我每一天晚...
#
#                                      title_text_list  \
# 0  [林志颖, 老婆, 深夜, 面膜, 睫毛, 吓人, 早年, 志颖, kimi, 爸爸, 当时...
# 1  [夸杨幂, 身材, 回复, 精彩, 。翩若, 惊鸿, 婉若, 游龙, 曹植, 形容, 洛神,...
# 2  [年轻, 风华绝代, 祝福, 世纪, 香港, 影视界, 涌现, 不少, 高颜值, 女星, 大...
# 3  [林心, 霍建华, 生活, 怼蹭, 老公, 人气, 霍建华, 心如, 1905, 电影, 网...
# 4  [TVB, 颜值, 担当, 近照, 曝光, 发现, 知道, TVB, 剧集, 长大, 小时候...
#
#                                          result_dict
# 0  {'陈若仪': 0.42043875007548426, '睫毛': 0.126762024...
# 1  {'洛神': 0.3089820469477368, '张钧甯': 0.2172754939...
# 2  {'蓝洁瑛': 0.6918540227764125, '生日': 0.1292081837...
# 3  {'霍建华': 0.7722662755178248, '林心': 0.4401862939...
# 4  {'姚莹莹': 0.24113865228565598, 'TVB': 0.11166514...

# %%
keyword_set = set()
for keyword_list in train_doc_keyword_df['keyword_list']:
    for keyword in keyword_list:
        keyword_set.add(keyword)

def get_deal_result_list(keyword_set, sample_df):
    temp_df = pd.DataFrame(columns=['id', 'result_list'])
    for temp_id, title_list, result_dict in sample_df[['id', 'title_list', 'result_dict']].values:
        title_set = set(title_list)
        keys = list(result_dict.keys())
        result_list = list()
        result_list_1 = list()
        result_list_2 = list()
        result_list_3 = list()
        result_list_4 = list()
        for title in title_set:
            if len(title) >= 5:
                result_list.append(title)
        for key in keys:
            if key in set(result_list):
                continue
            if((key in keyword_set) & (key in title_set)):
                result_list_1.append(key)
            else:
                if key in keyword_set:
                    result_list_2.append(key)
                else:
                    if key in title_set:
                        result_list_3.append(key)
                    else:
                        result_list_4.append(key)
        result_list = result_list + result_list_1 + result_list_3 + result_list_2 + result_list_4
        temp = pd.DataFrame([[temp_id, result_list]], columns=['id', 'result_list'])
        temp_df = pd.concat([temp_df, temp])
    print(temp_df.head())
    sample_df = pd.merge(sample_df, temp_df, on='id', how='left')
    return sample_df

def get_top_n_word(result_list, n):
    if len(result_list) < n:
        return '无'
    else:
        return result_list[n - 1]
    
sample_df = get_deal_result_list(keyword_set, sample_df)
sample_df['label1'] = sample_df['result_list'].map(lambda x: get_top_n_word(x, 1))
sample_df['label2'] = sample_df['result_list'].map(lambda x: get_top_n_word(x, 2))
print(sample_df.head())
# Out:
#         id              result_list
# 0  D000001    [睫毛, 面膜, 陈若仪, 安利, 日常]
# 0  D000002  [夸杨幂, 张钧甯, 洛神, 。翩若, 瓌姿]
# 0  D000003  [风华绝代, 生日, 妩媚, 蓝洁瑛, 有型]
# 0  D000004   [霍建华, 林心, 心如, 林心如, 索吻]
# 0  D000005   [TVB, 素颜, 姚莹莹, 药房, 剧集]
#         id label1 label2                title  \
# 0  D000001     睫毛     面膜   林志颖老婆深夜敷面膜，睫毛太长好吓人
# 1  D000002    夸杨幂    张钧甯   小s夸杨幂身材好，杨幂回复太精彩了！
# 2  D000003   风华绝代     生日    年轻时的她风华绝代，现却无人送祝福
# 3  D000004    霍建华     林心   林心如屡曝霍建华私生活被怼蹭老公人气
# 4  D000005    TVB     素颜  曾是TVB颜值担当，近照曝光发现真老了
#
#                                                 text  \
# 0  早年林志颖带kimi上《爸爸去哪儿》的时候，当时遮遮掩掩的林志颖老婆低调探班，总让人觉得格外...
# 1  翩若惊鸿，婉若游龙。曹植形容洛神的这两句，实在太抽象，以至于始终寻不到承受对象。直到在《大军...
# 2  上个世纪香港影视界涌现出了不少高颜值女星，在《大话西游之月光宝盒》中饰演春三十娘和蜘蛛精的蓝...
# 3  霍建华林心如1905电影网讯近日，林心如在接受采访时爆料称老公霍建华会主动向女儿索吻，笑称他...
# 4  不知道有多少人是看TVB剧集长大的，小时候我每一天晚上都会守着电视看TVB剧集的。可以说对于...
#
#                   title_list  \
# 0  [林志颖, 老婆, 深夜, 面膜, 睫毛, 吓人]
# 1          [夸杨幂, 身材, 回复, 精彩]
# 2             [年轻, 风华绝代, 祝福]
# 3  [林心, 霍建华, 生活, 怼蹭, 老公, 人气]
# 4  [TVB, 颜值, 担当, 近照, 曝光, 发现]
#
#                                            text_list  \
# 0  [早年, 志颖, kimi, 爸爸, 当时, 遮遮掩掩, 志颖, 老婆, 低调, 探班, 觉...
# 1  [翩若, 惊鸿, 婉若, 游龙, 曹植, 形容, 洛神, 实在, 抽象, 始终, 承受, 对...
# 2  [世纪, 香港, 影视界, 涌现, 不少, 高颜值, 女星, 大话, 西游, 光宝盒, 饰演...
# 3  [霍建华, 心如, 1905, 电影, 网讯, 近日, 林心如, 接受, 采访, 爆料, 老...
# 4  [知道, TVB, 剧集, 长大, 小时候, 晚上, 电视, TVB, 剧集, 时期, TV...
#
#                                           title_text  \
# 0  林志颖老婆深夜敷面膜，睫毛太长好吓人。早年林志颖带kimi上《爸爸去哪儿》的时候，当时遮遮掩...
# 1  小s夸杨幂身材好，杨幂回复太精彩了！。翩若惊鸿，婉若游龙。曹植形容洛神的这两句，实在太抽象，...
# 2  年轻时的她风华绝代，现却无人送祝福。上个世纪香港影视界涌现出了不少高颜值女星，在《大话西游之...
# 3  林心如屡曝霍建华私生活被怼蹭老公人气。霍建华林心如1905电影网讯近日，林心如在接受采访时爆...
# 4  曾是TVB颜值担当，近照曝光发现真老了。不知道有多少人是看TVB剧集长大的，小时候我每一天晚...
#
#                                      title_text_list  \
# 0  [林志颖, 老婆, 深夜, 面膜, 睫毛, 吓人, 早年, 志颖, kimi, 爸爸, 当时...
# 1  [夸杨幂, 身材, 回复, 精彩, 。翩若, 惊鸿, 婉若, 游龙, 曹植, 形容, 洛神,...
# 2  [年轻, 风华绝代, 祝福, 世纪, 香港, 影视界, 涌现, 不少, 高颜值, 女星, 大...
# 3  [林心, 霍建华, 生活, 怼蹭, 老公, 人气, 霍建华, 心如, 1905, 电影, 网...
# 4  [TVB, 颜值, 担当, 近照, 曝光, 发现, 知道, TVB, 剧集, 长大, 小时候...
#
#                                          result_dict              result_list
# 0  {'陈若仪': 0.42043875007548426, '睫毛': 0.126762024...    [睫毛, 面膜, 陈若仪, 安利, 日常]
# 1  {'洛神': 0.3089820469477368, '张钧甯': 0.2172754939...  [夸杨幂, 张钧甯, 洛神, 。翩若, 瓌姿]
# 2  {'蓝洁瑛': 0.6918540227764125, '生日': 0.1292081837...  [风华绝代, 生日, 妩媚, 蓝洁瑛, 有型]
# 3  {'霍建华': 0.7722662755178248, '林心': 0.4401862939...   [霍建华, 林心, 心如, 林心如, 索吻]
# 4  {'姚莹莹': 0.24113865228565598, 'TVB': 0.11166514...   [TVB, 素颜, 姚莹莹, 药房, 剧集]

# %%
print(sample_df[['id', 'result_list', 'title_list']].head(50))
# Out:
#          id                      result_list  \
# 0   D000001            [睫毛, 面膜, 陈若仪, 安利, 日常]
# 1   D000002          [夸杨幂, 张钧甯, 洛神, 。翩若, 瓌姿]
# 2   D000003          [风华绝代, 生日, 妩媚, 蓝洁瑛, 有型]
# 3   D000004           [霍建华, 林心, 心如, 林心如, 索吻]
# 4   D000005           [TVB, 素颜, 姚莹莹, 药房, 剧集]
# 5   D000006             [公主, 冰冰, 塞娅, 惊艳, 金锁]
# 6   D000007           [周冬雨, 周迅, 小晓, 老孙, 林见东]
# 7   D000008             [张杰, 自嘲, 废物, 劈柴, 企鹅]
# 8   D000009           [主编, 少女味, 29日, 托腮, 张宇]
# 9   D000010            [男装, 节目, 大幂幂, 预告, 看杨]
# 10  D000011            [彦祖, 蒋怡, 篮球, 翁狄森, 球例]
# 11  D000012            [甄嬛, 婚纱照, 剧外, 娘娘, 剧中]
# 12  D000013            [志玲, 花娇, 壁花, 花仙子, 美腻]
# 13  D000014           [主持人, 节目, 主持, 综艺, 撒贝宁]
# 14  D000015        [沈春阳, 沈阳, 素颜长, 溜达, 风和日丽拍]
# 15  D000016            [冠希, 陈冠希, 女儿, 滚君, 父亲]
# 16  D000017          [张艺谋, 陈婷, 艺谋, 张伟平, 周晓枫]
# 17  D000018            [超模, 刘雯, 模特, 模特界, 何穗]
# 18  D000019         [祝绪丹, 饰演, 紫明宫, 白浅大, 唐楠楠]
# 19  D000020            [漫威, 漫画, 英雄, DC, 古德曼]
# 20  D000021         [成龙, 吴卓林, Andi, 女友, 庇护所]
# 21  D000022            [郑凯, 肖小军, 刘婷, 韩露, 郑恺]
# 22  D000023           [杨洋, 孙怡, 王珞丹, 李沁, 邢昭林]
# 23  D000024           [虐心, 正圆, 周莹, 二少爷, 赵白石]
# 24  D000025            [小斐, 贾玲, 智商, ​​, 冯巩干]
# 25  D000026            [种田, 女主, 黑风寨, 男主, 甜宠]
# 26  D000027             [裙子, 吐槽, 整容, 配得, 估计]
# 27  D000028             [爱情, 铁木, 冥王, 魔族, 草原]
# 28  D000029             [张翰, 湖南, 平凡, 感恩, 时光]
# 29  D000030           [笑容, 垣结衣, 治愈系, 表姐, 松韵]
# 30  D000031        [周杰伦, 刘嘉玲, 邱淑贞, 梁朝伟, 梁家辉]
# 31  D000032         [立陶宛, 图米纳斯, VMT, 剧院, 假面]
# 32  D000033           [导演, ​​​, 安生, 不可悲, ​许]
# 33  D000034             [唐僧, 许仙, 青蛇, 法海, 白蛇]
# 34  D000035            [奇隆, 纯天然, 黎明, 巅峰, 彦祖]
# 35  D000036           [蚁人, 黄蜂女, 幽灵, 营救法, 霍普]
# 36  D000037            [婚姻, 别离, 契约, 李小冉, 秋阳]
# 37  D000038         [冠希, 女儿, 女星, alaia, 责任心]
# 38  D000039            [长发, 灏明, 易烊, 男星, 罗志祥]
# 39  D000040           [电影, 林见清, 爱情, 前任, 方小晓]
# 40  D000041      [手机, 定档, 陌生人, 保罗·格诺维塞, 热议度]
# 41  D000042            [张翰, 闹翻, 武警, 反恐特, 叶烁]
# 42  D000043          [韩国, 张国荣, 女神, 王祖贤, 袁洁莹]
# 43  D000044  [Kyson, 陈若仪, Jesnson, 动物园, 双子星]
# 44  D000045         [周冬雨, 飞机场, 娱乐圈, 硅胶胸, 舆论]
# 45  D000046             [票房, 战争, 漫威, 无限, 电影]
# 46  D000047           [周杰伦, 抢镜, 妈妈, 身后, 叶惠美]
# 47  D000048             [金星, 激素, 女人, 节目, 走红]
# 48  D000049             [科技, 城墙, 吴艳, 光影, 西安]
# 49  D000050            [叶佳, 美食, 丹妮, 叶佳瑶, 食神]
#
#                                      title_list
# 0                     [林志颖, 老婆, 深夜, 面膜, 睫毛, 吓人]
# 1                             [夸杨幂, 身材, 回复, 精彩]
# 2                                [年轻, 风华绝代, 祝福]
# 3                     [林心, 霍建华, 生活, 怼蹭, 老公, 人气]
# 4                     [TVB, 颜值, 担当, 近照, 曝光, 发现]
# 5                          [16, 冰冰, 塞娅, 公主, 惊艳]
# 6                                 [北京, 周迅, 周冬雨]
# 7                     [张杰, 自嘲, 废物, 赞谢娜, 时代, 女性]
# 8                    [杂志, 主编, 夸奖, 大幂幂, 越来越, 漂亮]
# 9                          [男装, 现身, 节目, 瞬间, 年轻]
# 10                     [搭戏, 彦祖, 出名, 如今, 40, 迎来]
# 11                   [尴尬, 灏明, 音乐节, 卫生间, 突然, 拉开]
# 12                         [仙女, 本人, 43, 志玲, 花娇]
# 13              [主持人, 霸屏, 哪般, 提升, 能力, 与时俱进, 关键]
# 14                   [沈阳, 妻子, 外出, 散步, 沈春阳, 素颜长]
# 15                                   [怼天怼地, 冠希]
# 16               [张艺谋, 太太, 首度, 受访, 老谋子, 爱情, 故事]
# 17        [中国, 国际, 超模, 排行榜, 出炉, 第一, 意料, 之中, 争议]
# 18                   [出演, 三生, 如今, 片约, 不断, 销声匿迹]
# 19               [漫威, 漫画, 发展史, 发行, 电影, 具有, 说服力]
# 20                    [后来, 票房, 10亿, 华语, 影史, 导演]
# 21            [虐狗, 神剧, 开播, 收视率, 轻松, 破亿, 郑凯, 原因]
# 22                    [撞衫, 可怕, 尴尬, 看看, 娱乐圈, 明星]
# 23                    [回顾, 电视剧, 那年, 正圆, 结局, 虐心]
# 24             [不要, 出名, 头脑, 娱乐, 名媛, 小斐, 谨慎, 前行]
# 25                                         [种田]
# 26                         [吐槽, 裙子, 大步, 走路, 吐槽]
# 27                                     [战神, 爱情]
# 28                 [张翰, 湖南, 卫视, 回忆, 演艺, 生涯, 感慨]
# 29               [27, 谭松韵, 17, 娱乐圈, 第一, 元气, 女神]
# 30  [地表, 应援团, 周杰伦, 刘嘉玲, 梁朝伟, 张家辉, 邱淑贞, 组团, 演唱会]
# 31   [静安, 戏剧, 汇集, 外国, 名团, 立陶宛, 国宝级, 导演, 带来, 力作]
# 32                  [后来, 方小晓, 扮演者, 周冬雨, 主演, 电影]
# 33        [电影, 电视剧, 长大, 原来, 唐僧, 真的, 喜欢, 女儿, 国王]
# 34               [吴彦祖, 黎明, 奇隆, 颜值, 巅峰, 年代, 纯天然]
# 35                [娱乐圈, 明星, 女友, 鹿晗, 眼神, 宠溺, 网友]
# 36                   [别离, 李小冉, 演绎, 契约, 婚姻, 轻喜剧]
# 37                         [冠希, 男人, 男人, 转变, 过程]
# 38         [男星, 长发, 杀马特, 灏明, 玛丽苏, 易烊, 千玺颠覆, 形象]
# 39                       [后来, 无病呻吟, 有点, 过时, 土气]
# 40                             [好友, 手机, 不止, 秘密]
# 41                         [张翰, 闹翻, 许久, 联系, 关系]
# 42           [八九十, 年代, 明星, 韩国, 人人, 喜欢, 张国荣, 希望]
# 43             [生活, 真实, 超越, 电影, 后来, 没有, 告诉, 真理]
# 44                       [飞机场, 女王, 周冬雨, 简单, 样子]
# 45                [漫威, 复仇者, 联盟, 无限, 战争, 票房, 历史]
# 46                    [周杰伦, 妈妈, 撞衫, 身后, 女人, 抢镜]
# 47                [金星, 曝光, 男人味, 十足, 网友, 激素, 反差]
# 48                                 [科技, 城墙, 夜空]
# 49                     [叶佳, 金句, 合集, 情话, 剧超, 好看]

# %%
# 导出预测结果
def exportResult(df, fileName):
    df.to_csv('../../result/chusai/%s.csv' % fileName, header=True, index=False)
    
exportResult(sample_df[['id', 'label1', 'label2']], 'tfidf_9_5_3')
