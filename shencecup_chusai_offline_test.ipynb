# %%
import pandas as pd
import numpy as np
import datetime
import math
from gensim import corpora, models
from pyltp import SentenceSplitter
import functools
import os
from pyltp import Segmentor
from pyltp import Postagger
import jieba
import jieba.posseg as psg
from jieba import analyse
import re

# %%
all_docs_df = pd.read_csv('../../data/chusai/all_docs.txt', sep='\001', header=None)
all_docs_df.columns = ['id', 'title', 'text']
all_docs_df['title'] = all_docs_df['title'].astype(str)
all_docs_df['text'] = all_docs_df['text'].astype(str)
print(all_docs_df.info())
print(all_docs_df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108295 entries, 0 to 108294
# Data columns (total 3 columns):
# id       108295 non-null object
# title    108295 non-null object
# text     108295 non-null object
# dtypes: object(3)
# memory usage: 2.5+ MB
# None
#         id                title  \
# 0  D000001   林志颖老婆深夜敷面膜，睫毛太长好吓人
# 1  D000002   小s夸杨幂身材好，杨幂回复太精彩了！
# 2  D000003    年轻时的她风华绝代，现却无人送祝福
# 3  D000004   林心如屡曝霍建华私生活被怼蹭老公人气
# 4  D000005  曾是TVB颜值担当，近照曝光发现真老了
#
#                                                 text
# 0  早年林志颖带kimi上《爸爸去哪儿》的时候，当时遮遮掩掩的林志颖老婆低调探班，总让人觉得格外...
# 1  翩若惊鸿，婉若游龙。曹植形容洛神的这两句，实在太抽象，以至于始终寻不到承受对象。直到在《大军...
# 2  上个世纪香港影视界涌现出了不少高颜值女星，在《大话西游之月光宝盒》中饰演春三十娘和蜘蛛精的蓝...
# 3  霍建华林心如1905电影网讯近日，林心如在接受采访时爆料称老公霍建华会主动向女儿索吻，笑称他...
# 4  不知道有多少人是看TVB剧集长大的，小时候我每一天晚上都会守着电视看TVB剧集的。可以说对于...

# %%
train_doc_keyword_df = pd.read_csv('../../data/chusai/train_docs_keywords.txt', sep='\t', header=None)
train_doc_keyword_df.columns = ['id', 'keyword']
train_doc_keyword_df['keyword_list'] = train_doc_keyword_df['keyword'].map(lambda x: x.split(','))
print(train_doc_keyword_df.head(30))
# Out:
#          id             keyword             keyword_list
# 0   D012650          三生三世,凤九,东华           [三生三世, 凤九, 东华]
# 1   D047118               南宁,美食                 [南宁, 美食]
# 2   D098970              凉菜,北京人                [凉菜, 北京人]
# 3   D092010           华为,P30pro             [华为, P30pro]
# 4   D103408              酒吧,世界杯                [酒吧, 世界杯]
# 5   D103809             烧烤,人生一串               [烧烤, 人生一串]
# 6   D003823          惠若琪,杨颖,奔跑吧           [惠若琪, 杨颖, 奔跑吧]
# 7   D023499   我与你的光年距离2,王以纶,许晓诺    [我与你的光年距离2, 王以纶, 许晓诺]
# 8   D063937           无人机,军用,美军            [无人机, 军用, 美军]
# 9   D059085            女兵,剪影,欧美             [女兵, 剪影, 欧美]
# 10  D045459         增肌,器械,哑铃,杠铃         [增肌, 器械, 哑铃, 杠铃]
# 11  D069093         支教,艺术,乡村,儿童         [支教, 艺术, 乡村, 儿童]
# 12  D082165             第三世界,游戏               [第三世界, 游戏]
# 13  D071067               蛋糕,宝宝                 [蛋糕, 宝宝]
# 14  D004539         纪念品,蒂尔达·斯文顿           [纪念品, 蒂尔达·斯文顿]
# 15  D057452        叙利亚,俄罗斯,S300         [叙利亚, 俄罗斯, S300]
# 16  D008361               王源,微博                 [王源, 微博]
# 17  D056561          美国,战斧,巡航导弹           [美国, 战斧, 巡航导弹]
# 18  D088615            黄子韬,糖果手机              [黄子韬, 糖果手机]
# 19  D087839              装修,实战经                [装修, 实战经]
# 20  D105525               茄子,家常                 [茄子, 家常]
# 21  D088954  倪光南,芯片,操作系统,Wintel  [倪光南, 芯片, 操作系统, Wintel]
# 22  D049827              高血压,吃肉                [高血压, 吃肉]
# 23  D071661               照片,拍法                 [照片, 拍法]
# 24  D032085           扶摇,楚乔传,杨幂            [扶摇, 楚乔传, 杨幂]
# 25  D077124      时尚,穿搭,AndrewGn       [时尚, 穿搭, AndrewGn]
# 26  D050297            减肥,按摩,脚底             [减肥, 按摩, 脚底]
# 27  D040450              哈勒普,小威                [哈勒普, 小威]
# 28  D090693              微信,支付宝                [微信, 支付宝]
# 29  D085341           装修,卫生间,地漏            [装修, 卫生间, 地漏]

# %%
train_doc_keyword_df = pd.merge(train_doc_keyword_df, all_docs_df, on='id', how='left')
jieba.load_userdict('user_dict.txt')

# %%
LTP_DATA_DIR = '../../ltp/ltp_data_v3.4.0/'  # ltp模型目录的路径
cws_model_path = os.path.join(LTP_DATA_DIR, 'cws.model')  # 分词模型路径，模型名称为`cws.model`
segmentor = Segmentor()  # 初始化实例
segmentor.load(cws_model_path)  # 加载模型

pos_model_path = os.path.join(LTP_DATA_DIR, 'pos.model')  # 词性标注模型路径，模型名称为`pos.model`
postagger = Postagger() # 初始化实例
postagger.load(pos_model_path)  # 加载模型

# %%
#停用词表加载方法
def get_stopword_list():
    #停用词表存储路径，每一行为一个词，按行读取进行加载
    #进行编码转换确保匹配准确率
    stop_word_path = '../stopword.txt'
    stop_word_list = [sw.replace('\n', '') for sw in open(stop_word_path).readlines()]
    return stop_word_list

#分词方法，调用结巴接口
def jieba_seg_to_list(sentence, pos=False):
    if not pos:
        #不进行词性标注的分词方法
        seg_list = jieba.cut(sentence)
    else:
        #进行词性标注的分词方法
        seg_list = psg.cut(sentence)
    return seg_list

#去除干扰词
def jieba_word_filter(seg_list, stopword_list, pos=False):
    
    filter_list = []
    #根据pos参数选择是否词性过滤
    #不进行词性过滤，则将词性都标记为n，表示全部保留
    for seg in seg_list:
        if not pos:
            word = seg
            flag = 'n'
        else:
            word = seg.word
            flag = seg.flag
        if not flag.startswith('n'):
            continue
        #过滤高停用词表中的词，以及长度为<2的词
        if not word in stopword_list and len(word) > 1:
            filter_list.append(word)
    
    return filter_list

def jieba_word_deal(sentence, stopword_list, pos=False):
    #调用上面方式对数据集进行处理，处理后的每条数据仅保留非干扰词
    seg_list = jieba_seg_to_list(sentence, pos)
    filter_list = jieba_word_filter(seg_list, stopword_list, pos)
    return filter_list

#分词方法，调用ltp接口
def ltp_seg_to_list(sentence):
    words = segmentor.segment(sentence)  # 分词
    seg_list = list(words)
    return seg_list

#去除干扰词
def ltp_word_filter(seg_list, stopword_list):
    
    filter_list = []
    #根据pos参数选择是否词性过滤
    #不进行词性过滤，则将词性都标记为n，表示全部保留
    for seg in seg_list:
        #过滤高停用词表中的词，以及长度为<2的词
        if not seg in stopword_list and len(seg) > 1:
            filter_list.append(seg)
    
    return filter_list

def ltp_word_deal(sentence, stopword_list):
    #调用上面方式对数据集进行处理，处理后的每条数据仅保留非干扰词
    seg_list = ltp_seg_to_list(sentence)
    filter_list = ltp_word_filter(seg_list, stopword_list)
    return filter_list

def get_title_person_name(title_list):
    attributes_list = list(postagger.postag(title_list))
    title_person_name_list = list()
    i = 0
    for attributes in attributes_list:
        if attributes == 'nh':
            title_person_name_list.append(title_list[i])
        i = i + 1
    return title_person_name_list

def get_text_sentences(text):
    sentences_list = SentenceSplitter.split(text)
    return sentences_list

train_doc_keyword_df['text_sentences'] = train_doc_keyword_df['text'].map(lambda x: get_text_sentences(x))
train_doc_keyword_df['text_sentences_len'] = train_doc_keyword_df['text_sentences'].map(lambda x: len(x))

def get_title_text(all_docs_df):
    temp_df = pd.DataFrame(columns=['id', 'title_text'])
    for temp_id, title, text, text_sentences_len in all_docs_df[['id', 'title', 'text', 'text_sentences_len']].values:
        length = math.ceil(text_sentences_len * 0.4)
        if length < 6:
            length = 6
#         if length > 15:
#             length = 15
        title_text = ''
        for i in range(length):
            title_text = title + '。' + title_text
        title_text = title_text + text
        temp = pd.DataFrame([[temp_id, title_text]], columns=['id', 'title_text'])
        temp_df = pd.concat([temp_df, temp])
    all_docs_df = pd.merge(all_docs_df, temp_df, on='id', how='left')
    return all_docs_df

stopword_list = get_stopword_list()
train_doc_keyword_df['jieba_title_list'] = train_doc_keyword_df['title'].map(lambda x : jieba_word_deal(x, stopword_list, False))
# all_docs_df['jieba_title_list_for_name'] = all_docs_df['title'].map(lambda x : jieba_word_deal(x, stopword_list, False))
# all_docs_df['title_text'] = all_docs_df['title'] + '。' + all_docs_df['title'] + '。' + all_docs_df['title'] + '。' + all_docs_df['title'] + '。' + all_docs_df['title'] + '。' + all_docs_df['title'] + '。' + all_docs_df['text']
train_doc_keyword_df = get_title_text(train_doc_keyword_df)
train_doc_keyword_df['jieba_title_text_list'] = train_doc_keyword_df['title_text'].map(lambda x : jieba_word_deal(x, stopword_list, False))

train_doc_keyword_df['ltp_title_list'] = train_doc_keyword_df['title'].map(lambda x : ltp_word_deal(x, stopword_list))
train_doc_keyword_df['ltp_title_text_list'] = train_doc_keyword_df['title_text'].map(lambda x : ltp_word_deal(x, stopword_list))

train_doc_keyword_df['jieba_title_person_name_list'] = train_doc_keyword_df['jieba_title_list'].map(lambda x: get_title_person_name(x))
train_doc_keyword_df['ltp_title_person_name_list'] = train_doc_keyword_df['ltp_title_list'].map(lambda x: get_title_person_name(x))

print(train_doc_keyword_df.head(10))
# Out:
#         id            keyword           keyword_list  \
# 0  D012650         三生三世,凤九,东华         [三生三世, 凤九, 东华]
# 1  D047118              南宁,美食               [南宁, 美食]
# 2  D098970             凉菜,北京人              [凉菜, 北京人]
# 3  D092010          华为,P30pro           [华为, P30pro]
# 2                           []                         []
# 3                           []                         []
# 4                           []                         []
# 5                           []                         []
# 6                    [杨颖, 惠若琪]                      [杨颖跳]
# 7                   [王以纶, 许晓诺]                 [王以纶, 许晓诺]
# 8                           []                         []
# 9                           []                         []

# %%
#idf统计方法
def train_idf(doc_list):
    idf_dic = {}
    #总文档数
    tt_count = len(doc_list)
    
    #每个词出现的文档数
    for doc in doc_list:
        for word in set(doc):
            idf_dic[word] = idf_dic.get(word, 0.0) + 1.0
    
    #按公式转换为idf值，分母加1进行平滑处理
    for k, v in idf_dic.items():
        idf_dic[k] = math.log(tt_count / (1.0 + v))
        
    #对于没有在字典中的词，默认其尽在一个文档中出现，得到默认idf值
    default_idf = math.log(tt_count / (1.0))
    return idf_dic, default_idf

#排序函数，用于topK关键词的按值排
def cmp(e1, e2):
    res = np.sign(e1[1] - e2[1])
    if res != 0:
        return res
    else:
        a = e1[0] + e2[0]
        b = e2[0] + e1[0]
        if a > b:
            return 1
        elif a == b:
            return 0
        else:
            return -1

# %%
#TF-IDF类
class TfIdf(object):
    #四个参数分别是：训练好的idf字典，默认idf值，处理后的待提取文本，关键词数量
    def __init__(self, idf_dic, default_idf, word_list, keyword_num):
        self.word_list = word_list
        self.idf_dic = idf_dic
        self.default_idf = default_idf
        self.tf_dic = self.get_tf_dic()
        self.keyword_num = keyword_num
    
    #统计tf值
    def get_tf_dic(self):
        tf_dic = {}
        for word in self.word_list:
            tf_dic[word] = tf_dic.get(word, 0.0) + 1.0
        
        tt_count = len(self.word_list)
        for k, v in tf_dic.items():
            tf_dic[k] = float(v) / tt_count
        
        return tf_dic
    
    #按公式计算tf-idf
    def get_tfidf(self):
        tfidf_dic = {}
        for word in self.word_list:
            idf = self.idf_dic.get(word, self.default_idf)
            tf = self.tf_dic.get(word, 0)
            
            tfidf = tf * idf
            tfidf_dic[word] = tfidf
        
        result_dict = {}
        for k, v in sorted(tfidf_dic.items(), key=functools.cmp_to_key(cmp), reverse=True)[:self.keyword_num]:
            result_dict[k] = result_dict.get(k, 0.0) + float(v)
        return result_dict

# %%
jieba_idf_dic, jieba_default_idf = train_idf(train_doc_keyword_df['jieba_title_text_list'])
train_doc_keyword_df['jieba_result_dict_5'] = train_doc_keyword_df['jieba_title_text_list'].map(lambda x: TfIdf(jieba_idf_dic, jieba_default_idf, x, 5).get_tfidf())
train_doc_keyword_df['jieba_result_dict_10'] = train_doc_keyword_df['jieba_title_text_list'].map(lambda x: TfIdf(jieba_idf_dic, jieba_default_idf, x, 10).get_tfidf())
print(train_doc_keyword_df.head())
# Out:
#         id     keyword    keyword_list  \
# 0  D012650  三生三世,凤九,东华  [三生三世, 凤九, 东华]
# 1  D047118       南宁,美食        [南宁, 美食]
# 2  D098970      凉菜,北京人       [凉菜, 北京人]
# 3  D092010   华为,P30pro    [华为, P30pro]
# 4  D103408      酒吧,世界杯       [酒吧, 世界杯]
#
#                                     title  \
# 0          《三生三世》里凤九东华最有“夫妻相”，这一模一样的动作是证明
# 1        【味集】南宁美食圣地最强攻略！老南宁最爱的味道，都汇集在这些地方
# 3  [华为, 新机, P30pro, 曝光, 麒麟, 1020, 5G, 芯片, 网友, 小米,...
# 4  [泰晤士河, 餐厅, 酒吧, 世界杯, 进来, 泰晤士河, 餐厅, 酒吧, 世界杯, 进来,...
#
#                                       ltp_title_list  \
# 0                     [三生, 凤九, 东华, 夫妻, 一模一样, 动作, 证明]
# 1               [味集, 南宁, 美食, 圣地, 攻略, 南宁, 味道, 汇集, 地方]
# 2                                   [据说, 凉菜, 北京, 喜欢]
# 3  [华为, 新机皇, P30pro, 曝光, 麒麟, 1020, 5G, 芯片, 网友, 小米...
# 4                            [泰晤士河, 餐厅, 酒吧, 世界杯, 进来]
#
#                                  ltp_title_text_list  \
# 0  [三生, 凤九, 东华, 夫妻, 一模一样, 动作, 证明, 三生, 凤九, 东华, 夫妻,...
# 1  [味集, 南宁, 美食, 圣地, 攻略, 南宁, 味道, 汇集, 地方, 味集, 南宁, 美...
# 2  [据说, 凉菜, 北京, 喜欢, 据说, 凉菜, 北京, 喜欢, 据说, 凉菜, 北京, 喜...
# 3  [华为, 新机皇, P30pro, 曝光, 麒麟, 1020, 5G, 芯片, 网友, 小米...
# 4  [泰晤士河, 餐厅, 酒吧, 世界杯, 进来, 泰晤士河, 餐厅, 酒吧, 世界杯, 进来,...
#
#   jieba_title_person_name_list ltp_title_person_name_list  \
# 0                           []                         []
# 1                           []                         []
# 2                           []                         []
# 3                           []                         []
# 4                           []                         []
#
#                                  jieba_result_dict_5  \
# 0  {'东华': 0.3475555635230615, '三世': 0.33034381559...
# 1  {'南宁': 0.4146061030948719, '爱的味道': 0.203986686...
# 2  {'北京人': 0.3669701635688582, '凉菜': 0.3436352259...
# 3  {'P30pro': 0.2967186890493354, '华为': 0.2810028...
# 4  {'酒吧': 0.7145420011351142, '泰晤士河': 0.478400010...
#
#                                 jieba_result_dict_10
# 0  {'东华': 0.3475555635230615, '三世': 0.33034381559...
# 1  {'南宁': 0.4146061030948719, '爱的味道': 0.203986686...
# 2  {'北京人': 0.3669701635688582, '凉菜': 0.3436352259...
# 3  {'P30pro': 0.2967186890493354, '华为': 0.2810028...
# 4  {'酒吧': 0.7145420011351142, '泰晤士河': 0.478400010...

# %%
ltp_idf_dic, ltp_default_idf = train_idf(train_doc_keyword_df['ltp_title_text_list'])
train_doc_keyword_df['ltp_result_dict_5'] = train_doc_keyword_df['ltp_title_text_list'].map(lambda x: TfIdf(ltp_idf_dic, ltp_default_idf, x, 5).get_tfidf())
train_doc_keyword_df['ltp_result_dict_10'] = train_doc_keyword_df['ltp_title_text_list'].map(lambda x: TfIdf(ltp_idf_dic, ltp_default_idf, x, 10).get_tfidf())
print(train_doc_keyword_df.head())
# Out:
#         id     keyword    keyword_list  \
# 0  D012650  三生三世,凤九,东华  [三生三世, 凤九, 东华]
# 1  D047118       南宁,美食        [南宁, 美食]
# 2  D098970      凉菜,北京人       [凉菜, 北京人]
# 3  D092010   华为,P30pro    [华为, P30pro]
# 4  D103408      酒吧,世界杯       [酒吧, 世界杯]
#
#                                     title  \
# 3  [华为, 新机, P30pro, 曝光, 麒麟, 1020, 5G, 芯片, 网友, 小米,...
# 4  [泰晤士河, 餐厅, 酒吧, 世界杯, 进来, 泰晤士河, 餐厅, 酒吧, 世界杯, 进来,...
#
#                                       ltp_title_list  \
# 0                     [三生, 凤九, 东华, 夫妻, 一模一样, 动作, 证明]
# 1               [味集, 南宁, 美食, 圣地, 攻略, 南宁, 味道, 汇集, 地方]
# 2                                   [据说, 凉菜, 北京, 喜欢]
# 3  [华为, 新机皇, P30pro, 曝光, 麒麟, 1020, 5G, 芯片, 网友, 小米...
# 4                            [泰晤士河, 餐厅, 酒吧, 世界杯, 进来]
#
#                                  ltp_title_text_list  \
# 0  [三生, 凤九, 东华, 夫妻, 一模一样, 动作, 证明, 三生, 凤九, 东华, 夫妻,...
# 1  [味集, 南宁, 美食, 圣地, 攻略, 南宁, 味道, 汇集, 地方, 味集, 南宁, 美...
# 2  [据说, 凉菜, 北京, 喜欢, 据说, 凉菜, 北京, 喜欢, 据说, 凉菜, 北京, 喜...
# 3  [华为, 新机皇, P30pro, 曝光, 麒麟, 1020, 5G, 芯片, 网友, 小米...
# 4  [泰晤士河, 餐厅, 酒吧, 世界杯, 进来, 泰晤士河, 餐厅, 酒吧, 世界杯, 进来,...
#
#   jieba_title_person_name_list ltp_title_person_name_list  \
# 0                           []                         []
# 1                           []                         []
# 2                           []                         []
# 3                           []                         []
# 4                           []                         []
#
#                                  jieba_result_dict_5  \
# 0  {'东华': 0.3475555635230615, '三世': 0.33034381559...
# 1  {'南宁': 0.4146061030948719, '爱的味道': 0.203986686...
# 2  {'北京人': 0.3669701635688582, '凉菜': 0.3436352259...
# 3  {'P30pro': 0.2967186890493354, '华为': 0.2810028...
# 4  {'酒吧': 0.7145420011351142, '泰晤士河': 0.478400010...
#
#                                 jieba_result_dict_10  \
# 0  {'东华': 0.3475555635230615, '三世': 0.33034381559...
# 1  {'南宁': 0.4146061030948719, '爱的味道': 0.203986686...
# 2  {'北京人': 0.3669701635688582, '凉菜': 0.3436352259...
# 3  {'P30pro': 0.2967186890493354, '华为': 0.2810028...
# 4  {'酒吧': 0.7145420011351142, '泰晤士河': 0.478400010...
#
#                                    ltp_result_dict_5  \
# 0  {'东华': 0.4080000093531591, '三生': 0.37119112603...
# 1  {'南宁': 0.48652217104114054, '味集': 0.2292273478...
# 2  {'凉菜': 0.4355163023447493, '北京': 0.25255670410...
# 3  {'P30pro': 0.3073157850868117, '华为': 0.2910387...
# 4  {'酒吧': 0.7688110138795532, '泰晤士河': 0.514734189...
#
#                                   ltp_result_dict_10
# 0  {'东华': 0.4080000093531591, '三生': 0.37119112603...
# 1  {'南宁': 0.48652217104114054, '味集': 0.2292273478...
# 2  {'凉菜': 0.4355163023447493, '北京': 0.25255670410...
# 3  {'P30pro': 0.3073157850868117, '华为': 0.2910387...
# 4  {'酒吧': 0.7688110138795532, '泰晤士河': 0.514734189...

# %%
keyword_set = set()
for keyword_list in train_doc_keyword_df['keyword_list']:
    for keyword in keyword_list:
        keyword_set.add(keyword)

def get_deal_result_list(keyword_set, sample_df):
    temp_df = pd.DataFrame(columns=['id', 'result_list'])
    for temp_id, jieba_title_list, result_dict, jieba_title_person_name_list, ltp_title_person_name_list, title in sample_df[['id', 'jieba_title_list', 'jieba_result_dict_5', 'jieba_title_person_name_list', 'ltp_title_person_name_list', 'title']].values:
        show_list = list()
        word_list = re.findall(r"《(.+?)》", title)
        for word in word_list:
            if ',' in word:
                word = word.replace(',', '，')
                print(word)
            show_list.append(word)
        title_set = set(jieba_title_list)
        keys = list(result_dict.keys())
        title_person_name_set = set(jieba_title_person_name_list) & set(ltp_title_person_name_list)
#         title_person_name_set = set(jieba_title_person_name_list)
        result_list = list()
        result_list_1 = list()
        result_list_2 = list()
        result_list_3 = list()
        result_list_4 = list()
        result_list_5 = list()
        result_list_6 = list()
        result_list_7 = list()
        for title in title_set:
            if len(title) >= 5:
                result_list.append(title)
        for key in keys:
            if key in set(result_list):
                continue
            if((key in keyword_set) & (key in title_set)):
                result_list_1.append(key)
            else:
                if key in title_person_name_set:
                    result_list_5.append(key)
                else:
                    if (((key in set(jieba_title_person_name_list)) | (key in set(ltp_title_person_name_list))) & (len(key) >= 3)):
                        continue
                    else:
#                         if len(key) >=  3:
#                             result_list_7.append(key)
#                         else:
                        if key in keyword_set:
                            result_list_2.append(key)
                        else:
                            if key in title_set:
                                result_list_3.append(key)
                            else:
                                result_list_4.append(key)
        for name in set(jieba_title_person_name_list):
            if name in set(result_list_5):
                continue
            else:
                if len(name) >= 3:
                    result_list_6.append(name)
        for name in set(ltp_title_person_name_list):
            if ((name in set(result_list_5)) | (name in set(result_list_6))):
                continue
            else:
                if len(name) >= 3:
                    result_list_6.append(name)
#         result_list = result_list_1 + result_list + show_list + result_list_5 + result_list_6 + result_list_3 + result_list_2 + result_list_4
        result_list = result_list_5 + result_list_1 + result_list + show_list + result_list_6 +  result_list_3 + result_list_2 + result_list_4
        final_list = list()
        for result in result_list:
            if result not in final_list:
                final_list.append(result)
        temp = pd.DataFrame([[temp_id, final_list]], columns=['id', 'result_list'])
        temp_df = pd.concat([temp_df, temp])
    print(temp_df.head())
    sample_df = pd.merge(sample_df, temp_df, on='id', how='left')
    return sample_df

def get_top_n_word(result_list, n):
    if len(result_list) < n:
        return '无'
    else:
        return result_list[n - 1]
    
train_doc_keyword_df = get_deal_result_list(keyword_set, train_doc_keyword_df)
train_doc_keyword_df['label1'] = train_doc_keyword_df['result_list'].map(lambda x: get_top_n_word(x, 1))
train_doc_keyword_df['label2'] = train_doc_keyword_df['result_list'].map(lambda x: get_top_n_word(x, 2))
print(train_doc_keyword_df.head())
# Out:
#         id                    result_list
# 0  D012650  [东华, 三生三世, 三世, 三生, 里凤九, 一模一样]
# 0  D047118         [南宁, 爱的味道, 味集, 圣地, 汇集]
# 0  D098970        [北京人, 凉菜, 是这样吗, 下酒, 据说]
# 0  D092010     [华为, 5G, 麒麟, P30pro, 1020]
# 4  想在泰晤士河边餐厅酒吧看世界杯？戳进来就对啦。想在泰晤士河边餐厅酒吧看世界杯？戳进来就对啦。...
#
#                                jieba_title_text_list  ...    \
# 0  [三生, 三世, 里凤九, 东华, 最有, 夫妻, 一模一样, 动作, 证明, 三生, 三世...  ...
# 1  [味集, 南宁, 美食, 圣地, 最强, 攻略, 南宁, 爱的味道, 汇集, 地方, 味集,...  ...
# 2  [据说, 下酒, 凉菜, 北京人, 喜欢, 是这样吗, 据说, 下酒, 凉菜, 北京人, 喜...  ...
# 3  [华为, 新机, P30pro, 曝光, 麒麟, 1020, 5G, 芯片, 网友, 小米,...  ...
# 4  [泰晤士河, 餐厅, 酒吧, 世界杯, 进来, 泰晤士河, 餐厅, 酒吧, 世界杯, 进来,...  ...
#
#                                  ltp_title_text_list  \
# 0  [三生, 凤九, 东华, 夫妻, 一模一样, 动作, 证明, 三生, 凤九, 东华, 夫妻,...
# 1  [味集, 南宁, 美食, 圣地, 攻略, 南宁, 味道, 汇集, 地方, 味集, 南宁, 美...
# 2  [据说, 凉菜, 北京, 喜欢, 据说, 凉菜, 北京, 喜欢, 据说, 凉菜, 北京, 喜...
# 3  [华为, 新机皇, P30pro, 曝光, 麒麟, 1020, 5G, 芯片, 网友, 小米...
# 4  [泰晤士河, 餐厅, 酒吧, 世界杯, 进来, 泰晤士河, 餐厅, 酒吧, 世界杯, 进来,...
#
#   jieba_title_person_name_list ltp_title_person_name_list  \
# 0                           []                         []
# 1                           []                         []
# 2                           []                         []
# 3                           []                         []
# 4                           []                         []
#
#                                  jieba_result_dict_5  \
# 0  {'东华': 0.3475555635230615, '三世': 0.33034381559...
# 1  {'南宁': 0.4146061030948719, '爱的味道': 0.203986686...
# 2  {'北京人': 0.3669701635688582, '凉菜': 0.3436352259...
# 3  {'P30pro': 0.2967186890493354, '华为': 0.2810028...
# 4  {'酒吧': 0.7145420011351142, '泰晤士河': 0.478400010...
#
#                                 jieba_result_dict_10  \
# 0  {'东华': 0.3475555635230615, '三世': 0.33034381559...
# 1  {'南宁': 0.4146061030948719, '爱的味道': 0.203986686...
# 2  {'北京人': 0.3669701635688582, '凉菜': 0.3436352259...
# 3  {'P30pro': 0.2967186890493354, '华为': 0.2810028...
# 4  {'酒吧': 0.7145420011351142, '泰晤士河': 0.478400010...
#
#                                    ltp_result_dict_5  \
# 0  {'东华': 0.4080000093531591, '三生': 0.37119112603...
# 1  {'南宁': 0.48652217104114054, '味集': 0.2292273478...
# 2  {'凉菜': 0.4355163023447493, '北京': 0.25255670410...
# 3  {'P30pro': 0.3073157850868117, '华为': 0.2910387...
# 4  {'酒吧': 0.7688110138795532, '泰晤士河': 0.514734189...
#
#                                   ltp_result_dict_10  \
# 0  {'东华': 0.4080000093531591, '三生': 0.37119112603...
# 1  {'南宁': 0.48652217104114054, '味集': 0.2292273478...
# 2  {'凉菜': 0.4355163023447493, '北京': 0.25255670410...
# 3  {'P30pro': 0.3073157850868117, '华为': 0.2910387...
# 4  {'酒吧': 0.7688110138795532, '泰晤士河': 0.514734189...
#
#                      result_list label1 label2
# 0  [东华, 三生三世, 三世, 三生, 里凤九, 一模一样]     东华   三生三世
# 1         [南宁, 爱的味道, 味集, 圣地, 汇集]     南宁   爱的味道
# 2        [北京人, 凉菜, 是这样吗, 下酒, 据说]    北京人     凉菜
# 3     [华为, 5G, 麒麟, P30pro, 1020]     华为     5G
# 4        [酒吧, 世界杯, 餐厅, 泰晤士河, 进来]     酒吧    世界杯
#
# [5 rows x 21 columns]

# %%
print(train_doc_keyword_df[['keyword_list', 'result_list', 'text_sentences_len', 'title']].head(30))
# Out:
#                keyword_list                        result_list  \
# 0            [三生三世, 凤九, 东华]      [东华, 三生三世, 三世, 三生, 里凤九, 一模一样]
# 1                  [南宁, 美食]             [南宁, 爱的味道, 味集, 圣地, 汇集]
# 2                 [凉菜, 北京人]            [北京人, 凉菜, 是这样吗, 下酒, 据说]
# 3              [华为, P30pro]         [华为, 5G, 麒麟, P30pro, 1020]
# 4                 [酒吧, 世界杯]            [酒吧, 世界杯, 餐厅, 泰晤士河, 进来]
# 5                [烧烤, 人生一串]             [烧烤, 9.8, 气太, 市井, 纪录片]
# 6            [惠若琪, 杨颖, 奔跑吧]         [惠若琪, 杨颖跳, 公分, 跳高, 无情, 只离]
# 7     [我与你的光年距离2, 王以纶, 许晓诺]  [许晓诺, 王以纶, 我与你的光年距离2, 光年, 开机, 距离]
# 8             [无人机, 军用, 美军]              [无人机, 军用, 出口, 总量, 多大]
# 9              [女兵, 剪影, 欧美]             [女兵, 剪影, 欧美各国, 别有, 风情]
# 10         [增肌, 器械, 哑铃, 杠铃]               [哑铃, 杠铃, 器械, 增肌, 入门]
# 11         [支教, 艺术, 乡村, 儿童]               [艺术, 支教, 乡村, 儿童, 快乐]
# 12               [第三世界, 游戏]            [第三世界, 外包, 路漫漫, 外资, 抵触]
# 13                 [蛋糕, 宝宝]            [水果蛋糕, 手残党, 一学, 低油, 低糖]
# 14           [纪念品, 蒂尔达·斯文顿]     [纪念品, 海报, 女儿, 蒂尔达·斯文顿, 蒂尔, 斯文]
# 15         [叙利亚, 俄罗斯, S300]           [S300, 叙利亚, 俄罗斯, 不卖, 反悔]
# 16                 [王源, 微博]              [王源, 魔咒, 时不时, 最近, 小源]
# 17           [美国, 战斧, 巡航导弹]     [战斧, 巡航导弹, 弃用, 决定, DefenseOne]
# 18              [黄子韬, 糖果手机]        [翻译, 手机, 黄子韬, 糖果, S20, 翻译官]
# 19                [装修, 实战经]             [新房, 装修, 先见之明, 天亮, 实战]
# 20                 [茄子, 家常]               [茄子, 下入, 汤匙, 翻炒, 尖椒]
# 21  [倪光南, 芯片, 操作系统, Wintel]        [倪光南, 国产, Wintel, 衰落, 切实可行]
# 22                [高血压, 吃肉]          [高血压, 种肉, 只要吃, 没事, 高血压患者]
# 23                 [照片, 拍法]               [拍法, 照片, 日常, 新鲜, 模特]
# 24            [扶摇, 楚乔传, 杨幂]              [扶摇, 楚乔传, 相似, 究竟, 明白]
# 25       [时尚, 穿搭, AndrewGn]         [时尚, AndrewGn, 秀场, 点亮, 元素]
# 26             [减肥, 按摩, 脚底]               [减肥, 按摩, 搞定, 方法, 双脚]
# 27                [哈勒普, 小威]          [小威, 哈勒普, 哈勒, 网坛, 盼取, 幸事]
# 28                [微信, 支付宝]              [微信, 支付宝, 支付, 免费, 终结]
# 29            [装修, 卫生间, 地漏]              [地漏, 师傅, 卫生间, 装修, 排水]
#
#     text_sentences_len                                   title
# 0                   20          《三生三世》里凤九东华最有“夫妻相”，这一模一样的动作是证明
# 1                   96        【味集】南宁美食圣地最强攻略！老南宁最爱的味道，都汇集在这些地方
# 2                   66                  据说这些下酒凉菜，只有北京人喜欢，是这样吗？
# 3                   18  华为新机皇P30pro曝光：麒麟1020＋5G芯片，网友：小米要拿什么来抵挡
# 4                    3                  想在泰晤士河边餐厅酒吧看世界杯？戳进来就对啦
# 5                   78   看完真的会饿!有人把【烧烤】拍成了纪录片,怒摘9.8高分,市井烟火气太浓~
# 6                   18          杨颖跳高只离地10公分，被众人无情嘲笑，惠若琪：你打他牙干嘛
# 7                   29                 《我与你的光年距离2》开机王以纶许晓诺纷纷亮相
# 8                   16               我国军用无人机和美国差距多大？仅出口总量就差4倍多
# 9                    5                    最喜欢哪一款：别有风情的欧美各国女兵剪影
# 10                  33                    哑铃杠铃的4个动作，简单器械助你增肌入门
# 11                  30               艺术支教进乡村:让每一个儿童都享受到艺术带来的快乐
# 12                  98              低价外包、外资抵触——第三世界的游戏产业依旧长路漫漫
# 13                  39           最合适宝宝吃的水果蛋糕，低糖低油高营养，手残党也能一学就会
# 14                   4                   《纪念品》首曝海报蒂尔达·斯文顿与女儿合作
# 15                  14           叙利亚彻底无奈：说好的S300突然不卖了？俄罗斯为何反悔？
# 16                  10             王源最近是中了这个词的“魔咒”吗？时不时就······
# 17                   7                   因为这个原因，美国决定弃用“战斧”巡航导弹
# 18                  24        “AI翻译官”黄子韬出席助阵，全球首部翻译手机糖果S20将揭面纱
# 19                  61        住新房1年半，死磕到天亮，整理出20条装修实战经：不足+先见之明
# 20                   3           夏天，当属茄子最下饭了，分享8道家常茄子的做法，简单容易学
# 21                  16                  倪光南：Wintel已衰落国产替代切实可行！
# 22                  11              高血压能不能吃肉？最新医学发现，只要吃这3种肉就没事
# 23                  24                          日常的照片有什么新鲜的拍法？
# 24                  10              《扶摇》和《楚乔传》究竟有多相似看看这些你就明白了！
# 25                  15          秀场篇-带你看AndrewGn秀，时尚元素帮你点亮日常穿搭！
# 26                  24                           想减肥？3招按摩方法可搞定
# 27                  15                  哈勒普：小威回归是网坛幸事心态已成熟盼取佳绩
# 28                  53                  微信支付免费时代终结继续用微信还是用支付宝？
# 29                  10           卫生间装修，师傅安装地漏时做了个小改动，还说能靠墙又排水快

# %%
score1 = 0
score2 = 0
for label1, label2, keyword_list in train_doc_keyword_df[['label1', 'label2', 'keyword_list']].values:
    if label1 in keyword_list:
        score1 = score1 + 0.5
    if label2 in keyword_list:
        score2 = score2 + 0.5
print(score1)
print(score2)
# Out:
# 420.0
# 292.0
