# %%
import pandas as pd
import numpy as np
import datetime
import math
import jieba
import jieba.posseg as psg
from gensim import corpora, models
from jieba import analyse
import functools

# %%
all_docs_df = pd.read_csv('../../data/chusai/all_docs.txt', sep='\001', header=None)
all_docs_df.columns = ['id', 'title', 'text']
all_docs_df['title'] = all_docs_df['title'].astype(str)
all_docs_df['text'] = all_docs_df['text'].astype(str)
print(all_docs_df.info())
print(all_docs_df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108295 entries, 0 to 108294
# Data columns (total 3 columns):
# id       108295 non-null object
# title    108295 non-null object
# text     108295 non-null object
# dtypes: object(3)
# memory usage: 2.5+ MB
# None
#         id                title  \
# 0  D000001   林志颖老婆深夜敷面膜，睫毛太长好吓人
# 1  D000002   小s夸杨幂身材好，杨幂回复太精彩了！
# 2  D000003    年轻时的她风华绝代，现却无人送祝福
# 3  D000004   林心如屡曝霍建华私生活被怼蹭老公人气
# 4  D000005  曾是TVB颜值担当，近照曝光发现真老了
#
#                                                 text
# 0  早年林志颖带kimi上《爸爸去哪儿》的时候，当时遮遮掩掩的林志颖老婆低调探班，总让人觉得格外...
# 1  翩若惊鸿，婉若游龙。曹植形容洛神的这两句，实在太抽象，以至于始终寻不到承受对象。直到在《大军...
# 2  上个世纪香港影视界涌现出了不少高颜值女星，在《大话西游之月光宝盒》中饰演春三十娘和蜘蛛精的蓝...
# 3  霍建华林心如1905电影网讯近日，林心如在接受采访时爆料称老公霍建华会主动向女儿索吻，笑称他...
# 4  不知道有多少人是看TVB剧集长大的，小时候我每一天晚上都会守着电视看TVB剧集的。可以说对于...

# %%
train_doc_keyword_df = pd.read_csv('../../data/chusai/train_docs_keywords.txt', sep='\t', header=None)
train_doc_keyword_df.columns = ['id', 'keyword']
train_doc_keyword_df['keyword_list'] = train_doc_keyword_df['keyword'].map(lambda x: x.split(','))
print(train_doc_keyword_df.head(10))
# Out:
#         id            keyword           keyword_list
# 0  D012650         三生三世,凤九,东华         [三生三世, 凤九, 东华]
# 1  D047118              南宁,美食               [南宁, 美食]
# 2  D098970             凉菜,北京人              [凉菜, 北京人]
# 3  D092010          华为,P30pro           [华为, P30pro]
# 4  D103408             酒吧,世界杯              [酒吧, 世界杯]
# 5  D103809            烧烤,人生一串             [烧烤, 人生一串]
# 6  D003823         惠若琪,杨颖,奔跑吧         [惠若琪, 杨颖, 奔跑吧]
# 7  D023499  我与你的光年距离2,王以纶,许晓诺  [我与你的光年距离2, 王以纶, 许晓诺]
# 8  D063937          无人机,军用,美军          [无人机, 军用, 美军]
# 9  D059085           女兵,剪影,欧美           [女兵, 剪影, 欧美]

# %%
#给jieba添加自定义词
for keyword_list in train_doc_keyword_df['keyword_list']:
    for keyword in keyword_list:
        jieba.add_word(keyword)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model cost 1.109 seconds.
# Prefix dict has been built succesfully.

# %%
#停用词表加载方法
def get_stopword_list():
    #停用词表存储路径，每一行为一个词，按行读取进行加载
    #进行编码转换确保匹配准确率
    stop_word_path = '../stopword.txt'
    stop_word_list = [sw.replace('\n', '') for sw in open(stop_word_path).readlines()]
    return stop_word_list

#分词方法，调用结巴接口
def seg_to_list(sentence, pos=False):
    if not pos:
        #不进行词性标注的分词方法
        seg_list = jieba.cut(sentence)
    else:
        #进行词性标注的分词方法
        seg_list = psg.cut(sentence)
    return seg_list

#去除干扰词
def word_filter(seg_list, stopword_list, pos=False):
    
    filter_list = []
    #根据pos参数选择是否词性过滤
    #不进行词性过滤，则将词性都标记为n，表示全部保留
    for seg in seg_list:
        if not pos:
            word = seg
            flag = 'n'
        else:
            word = seg.word
            flag = seg.flag
        if not flag.startswith('n'):
            continue
        #过滤高停用词表中的词，以及长度为<2的词
        if not word in stopword_list and len(word) > 1:
            filter_list.append(word)
    
    return filter_list

def jieba_word_deal(sentence, stopword_list, pos=False):
    #调用上面方式对数据集进行处理，处理后的每条数据仅保留非干扰词
    seg_list = seg_to_list(sentence, pos)
    filter_list = word_filter(seg_list, stopword_list, pos)
    return filter_list

stopword_list = get_stopword_list()
all_docs_df['title_list'] = all_docs_df['title'].map(lambda x : jieba_word_deal(x, stopword_list, False))
all_docs_df['text_list'] = all_docs_df['text'].map(lambda x : jieba_word_deal(x, stopword_list, False))
all_docs_df['title_text'] = all_docs_df['title'] + '。' + all_docs_df['text']
all_docs_df['title_text_list'] = all_docs_df['title_text'].map(lambda x : jieba_word_deal(x, stopword_list, False))
print(all_docs_df.head(10))
# Out:
#         id                   title  \
# 0  D000001      林志颖老婆深夜敷面膜，睫毛太长好吓人
# 1  D000002      小s夸杨幂身材好，杨幂回复太精彩了！
# 2  D000003       年轻时的她风华绝代，现却无人送祝福
# 3  D000004      林心如屡曝霍建华私生活被怼蹭老公人气
# 4  D000005     曾是TVB颜值担当，近照曝光发现真老了
# 5  D000006  16岁的范冰冰有多美？塞娅公主看一眼被惊艳到
# 6  D000007        一样的北京，不一样的周迅与周冬雨
# 7  D000008      张杰自嘲是废物，赞谢娜是新时代好女性
# 8  D000009    杨幂获杂志主编夸奖：大幂幂瘦了越来越漂亮
# 9  D000010       杨幂女扮男装现身新节目瞬间年轻十岁
#
#                                                 text  \
# 0  早年林志颖带kimi上《爸爸去哪儿》的时候，当时遮遮掩掩的林志颖老婆低调探班，总让人觉得格外...
# 1  翩若惊鸿，婉若游龙。曹植形容洛神的这两句，实在太抽象，以至于始终寻不到承受对象。直到在《大军...
# 2  上个世纪香港影视界涌现出了不少高颜值女星，在《大话西游之月光宝盒》中饰演春三十娘和蜘蛛精的蓝...
# 3  霍建华林心如1905电影网讯近日，林心如在接受采访时爆料称老公霍建华会主动向女儿索吻，笑称他...
# 4  不知道有多少人是看TVB剧集长大的，小时候我每一天晚上都会守着电视看TVB剧集的。可以说对于...
# 5  范冰冰，家喻户晓的人物了，在出演还珠格格之前已经亭亭玉立十分美丽，在一些影剧中饰演一些小角色...
# 6  不知道刘若英与陈可辛之间有怎样的交情。《后来的我们》首映请来了陈可辛，他看完后笑着说很羡慕刘...
# 7  本文是企鹅号"不八卦会死人"原创文章，独家发布企鹅号，未经允许，不得转载!最新一期《向往的生...
# 8  网易娱乐4月29日报道  4月29日，时尚主编张宇晒出一组与杨幂的自拍合影，并发文：“今天与...
# 9  杨幂前段时间录制的综艺节目《我是大侦探》在4月29日播出预告，杨幂穿着校服的模样，甜死人了！...
#
#                        title_list  \
# 0   [林志颖, 老婆, 深夜, 面膜, 睫毛, 太长, 吓人]
# 1           [杨幂, 身材, 杨幂, 回复, 太精彩]
# 2             [年轻, 风华绝代, 无人, 送祝福]
# 3      [林心如, 曝霍, 建华, 私生活, 老公, 人气]
# 4      [TVB, 颜值, 担当, 照曝光, 发现, 真老]
# 5   [16, 范冰冰, 多美, 塞娅, 公主, 一眼, 惊艳]
# 6                   [北京, 周迅, 周冬雨]
# 7        [张杰, 自嘲, 废物, 谢娜, 时代, 女性]
# 8   [杨幂, 杂志, 主编, 夸奖, 大幂, 越来越, 漂亮]
# 9  [杨幂, 女扮男装, 现身, 节目, 瞬间, 年轻, 十岁]
#
#                                            text_list  \
# 0  [早年, 林志颖, kimi, 爸爸, 当时, 遮遮掩掩, 林志颖, 老婆, 低调, 探班,...
# 1  [翩若惊鸿, 婉若游龙, 曹植, 形容, 洛神, 两句, 实在太, 抽象, 始终, 不到, ...
# 2  [上个世纪, 香港, 影视界, 涌现出, 不少, 颜值, 女星, 大话西游, 月光宝盒, 饰...
# 3  [建华, 林心如, 1905, 电影, 网讯, 近日, 林心如, 接受, 采访, 爆料, 老...
# 4  [知道, TVB, 剧集, 长大, 小时候, 一天, 晚上, 电视, TVB, 剧集, 时期...
# 5  [范冰冰, 家喻户晓, 人物, 出演, 还珠格格, 之前, 已经, 亭亭玉立, 十分, 美丽...
# 6  [知道, 刘若英, 陈可辛, 之间, 交情, 后来的我们, 首映, 请来, 陈可辛, 看完,...
# 7  [本文, 企鹅, 八卦, 原创, 文章, 独家, 发布, 企鹅, 未经, 允许, 不得, 转...
# 8  [网易娱乐, 29, 报道, 29, 时尚, 主编, 张宇, 一组, 杨幂, 自拍, 合影,...
# 9  [杨幂, 前段时间, 录制, 综艺节目, 我是大侦探, 29, 播出, 预告, 杨幂, 穿着...
#
#                                           title_text  \
# 0  林志颖老婆深夜敷面膜，睫毛太长好吓人。早年林志颖带kimi上《爸爸去哪儿》的时候，当时遮遮掩...
# 1  小s夸杨幂身材好，杨幂回复太精彩了！。翩若惊鸿，婉若游龙。曹植形容洛神的这两句，实在太抽象，...
# 2  年轻时的她风华绝代，现却无人送祝福。上个世纪香港影视界涌现出了不少高颜值女星，在《大话西游之...
# 3  林心如屡曝霍建华私生活被怼蹭老公人气。霍建华林心如1905电影网讯近日，林心如在接受采访时爆...
# 4  曾是TVB颜值担当，近照曝光发现真老了。不知道有多少人是看TVB剧集长大的，小时候我每一天晚...
# 5  16岁的范冰冰有多美？塞娅公主看一眼被惊艳到。范冰冰，家喻户晓的人物了，在出演还珠格格之前已...
# 6  一样的北京，不一样的周迅与周冬雨。不知道刘若英与陈可辛之间有怎样的交情。《后来的我们》首映请...
# 7  张杰自嘲是废物，赞谢娜是新时代好女性。本文是企鹅号"不八卦会死人"原创文章，独家发布企鹅号，...
# 8  杨幂获杂志主编夸奖：大幂幂瘦了越来越漂亮。网易娱乐4月29日报道  4月29日，时尚主编张宇...
# 9  杨幂女扮男装现身新节目瞬间年轻十岁。杨幂前段时间录制的综艺节目《我是大侦探》在4月29日播出...
#
#                                      title_text_list
# 0  [林志颖, 老婆, 深夜, 面膜, 睫毛, 太长, 吓人, 早年, 林志颖, kimi, 爸...
# 1  [杨幂, 身材, 杨幂, 回复, 太精彩, 翩若惊鸿, 婉若游龙, 曹植, 形容, 洛神, ...
# 2  [年轻, 风华绝代, 无人, 送祝福, 上个世纪, 香港, 影视界, 涌现出, 不少, 颜值...
# 3  [林心如, 曝霍, 建华, 私生活, 老公, 人气, 建华, 林心如, 1905, 电影, ...
# 4  [TVB, 颜值, 担当, 照曝光, 发现, 真老, 知道, TVB, 剧集, 长大, 小时...
# 5  [16, 范冰冰, 多美, 塞娅, 公主, 一眼, 惊艳, 范冰冰, 家喻户晓, 人物, 出...
# 6  [北京, 周迅, 周冬雨, 知道, 刘若英, 陈可辛, 之间, 交情, 后来的我们, 首映,...
# 7  [张杰, 自嘲, 废物, 谢娜, 时代, 女性, 本文, 企鹅, 八卦, 原创, 文章, 独...
# 8  [杨幂, 杂志, 主编, 夸奖, 大幂, 越来越, 漂亮, 网易娱乐, 29, 报道, 29...
# 9  [杨幂, 女扮男装, 现身, 节目, 瞬间, 年轻, 十岁, 杨幂, 前段时间, 录制, 综...

# %%
#idf统计方法
def train_idf(doc_list):
    idf_dic = {}
    #总文档数
    tt_count = len(doc_list)
    
    #每个词出现的文档数
    for doc in doc_list:
        for word in set(doc):
            idf_dic[word] = idf_dic.get(word, 0.0) + 1.0
    
    #按公式转换为idf值，分母加1进行平滑处理
    for k, v in idf_dic.items():
        idf_dic[k] = math.log(tt_count / (1.0 + v))
        
    #对于没有在字典中的词，默认其尽在一个文档中出现，得到默认idf值
    default_idf = math.log(tt_count / (1.0))
    return idf_dic, default_idf

#排序函数，用于topK关键词的按值排
def cmp(e1, e2):
    res = np.sign(e1[1] - e2[1])
    if res != 0:
        return res
    else:
        a = e1[0] + e2[0]
        b = e2[0] + e1[0]
        if a > b:
            return 1
        elif a == b:
            return 0
        else:
            return -1

# %%
#TF-IDF类
class TfIdf(object):
    #四个参数分别是：训练好的idf字典，默认idf值，处理后的待提取文本，关键词数量
    def __init__(self, idf_dic, default_idf, word_list, keyword_num):
        self.word_list = word_list
        self.idf_dic = idf_dic
        self.default_idf = default_idf
        self.tf_dic = self.get_tf_dic()
        self.keyword_num = keyword_num
    
    #统计tf值
    def get_tf_dic(self):
        tf_dic = {}
        for word in self.word_list:
            tf_dic[word] = tf_dic.get(word, 0.0) + 1.0
        
        tt_count = len(self.word_list)
        for k, v in tf_dic.items():
            tf_dic[k] = float(v) / tt_count
        
        return tf_dic
    
    #按公式计算tf-idf
    def get_tfidf(self):
        tfidf_dic = {}
        for word in self.word_list:
            idf = self.idf_dic.get(word, self.default_idf)
            tf = self.tf_dic.get(word, 0)
            
            tfidf = tf * idf
            tfidf_dic[word] = tfidf
        
        result_dict = {}
        for k, v in sorted(tfidf_dic.items(), key=functools.cmp_to_key(cmp), reverse=True)[:self.keyword_num]:
            result_dict[k] = result_dict.get(k, 0.0) + float(v)
        return result_dict

# %%
idf_dic, default_idf = train_idf(all_docs_df['title_text_list'])
keyword_num = 5
all_docs_df['result_dict'] = all_docs_df['title_text_list'].map(lambda x: TfIdf(idf_dic, default_idf, x, keyword_num).get_tfidf())
print(all_docs_df.head())
# Out:
#         id                title  \
# 0  D000001   林志颖老婆深夜敷面膜，睫毛太长好吓人
# 1  D000002   小s夸杨幂身材好，杨幂回复太精彩了！
# 2  D000003    年轻时的她风华绝代，现却无人送祝福
# 3  D000004   林心如屡曝霍建华私生活被怼蹭老公人气
# 4  D000005  曾是TVB颜值担当，近照曝光发现真老了
#
#                                                 text  \
# 0  早年林志颖带kimi上《爸爸去哪儿》的时候，当时遮遮掩掩的林志颖老婆低调探班，总让人觉得格外...
# 1  翩若惊鸿，婉若游龙。曹植形容洛神的这两句，实在太抽象，以至于始终寻不到承受对象。直到在《大军...
# 2  上个世纪香港影视界涌现出了不少高颜值女星，在《大话西游之月光宝盒》中饰演春三十娘和蜘蛛精的蓝...
# 3  霍建华林心如1905电影网讯近日，林心如在接受采访时爆料称老公霍建华会主动向女儿索吻，笑称他...
# 4  不知道有多少人是看TVB剧集长大的，小时候我每一天晚上都会守着电视看TVB剧集的。可以说对于...
#
#                       title_list  \
# 0  [林志颖, 老婆, 深夜, 面膜, 睫毛, 太长, 吓人]
# 1          [杨幂, 身材, 杨幂, 回复, 太精彩]
# 2            [年轻, 风华绝代, 无人, 送祝福]
# 3     [林心如, 曝霍, 建华, 私生活, 老公, 人气]
# 4     [TVB, 颜值, 担当, 照曝光, 发现, 真老]
#
#                                            text_list  \
# 0  [早年, 林志颖, kimi, 爸爸, 当时, 遮遮掩掩, 林志颖, 老婆, 低调, 探班,...
# 1  [翩若惊鸿, 婉若游龙, 曹植, 形容, 洛神, 两句, 实在太, 抽象, 始终, 不到, ...
# 2  [上个世纪, 香港, 影视界, 涌现出, 不少, 颜值, 女星, 大话西游, 月光宝盒, 饰...
# 3  [建华, 林心如, 1905, 电影, 网讯, 近日, 林心如, 接受, 采访, 爆料, 老...
# 4  [知道, TVB, 剧集, 长大, 小时候, 一天, 晚上, 电视, TVB, 剧集, 时期...
#
#                                           title_text  \
# 0  林志颖老婆深夜敷面膜，睫毛太长好吓人。早年林志颖带kimi上《爸爸去哪儿》的时候，当时遮遮掩...
# 1  小s夸杨幂身材好，杨幂回复太精彩了！。翩若惊鸿，婉若游龙。曹植形容洛神的这两句，实在太抽象，...
# 2  年轻时的她风华绝代，现却无人送祝福。上个世纪香港影视界涌现出了不少高颜值女星，在《大话西游之...
# 3  林心如屡曝霍建华私生活被怼蹭老公人气。霍建华林心如1905电影网讯近日，林心如在接受采访时爆...
# 4  曾是TVB颜值担当，近照曝光发现真老了。不知道有多少人是看TVB剧集长大的，小时候我每一天晚...
#
#                                      title_text_list  \
# 0  [林志颖, 老婆, 深夜, 面膜, 睫毛, 太长, 吓人, 早年, 林志颖, kimi, 爸...
# 1  [杨幂, 身材, 杨幂, 回复, 太精彩, 翩若惊鸿, 婉若游龙, 曹植, 形容, 洛神, ...
# 2  [年轻, 风华绝代, 无人, 送祝福, 上个世纪, 香港, 影视界, 涌现出, 不少, 颜值...
# 3  [林心如, 曝霍, 建华, 私生活, 老公, 人气, 建华, 林心如, 1905, 电影, ...
# 4  [TVB, 颜值, 担当, 照曝光, 发现, 真老, 知道, TVB, 剧集, 长大, 小时...
#
#                                          result_dict
# 0  {'陈若仪': 0.3694296370148557, '睫毛': 0.1351004585...
# 1  {'张钧甯': 0.3084016205516576, '洛神': 0.2855570782...
# 2  {'蓝洁瑛': 0.5638080031961631, '风华绝代': 0.10505389...
# 3  {'建华': 0.7487552626390268, '林心如': 0.7431328710...
# 4  {'姚莹莹': 0.20642930082029642, 'TVB': 0.09534879...

# %%
sample_df = pd.read_csv('../../result/chusai/sample.csv', encoding='ISO-8859-1')
print(len(sample_df))
sample_df = pd.merge(sample_df, all_docs_df, on='id', how='left')
print(sample_df.head())
# Out:
# 107295
#         id label1 label2                title  \
# 0  D000001     ÎÞ     ÎÞ   林志颖老婆深夜敷面膜，睫毛太长好吓人
# 1  D000002     ÎÞ     ÎÞ   小s夸杨幂身材好，杨幂回复太精彩了！
# 2  D000003     ÎÞ     ÎÞ    年轻时的她风华绝代，现却无人送祝福
# 3  D000004     ÎÞ     ÎÞ   林心如屡曝霍建华私生活被怼蹭老公人气
# 4  D000005     ÎÞ     ÎÞ  曾是TVB颜值担当，近照曝光发现真老了
#
#                                                 text  \
# 0  早年林志颖带kimi上《爸爸去哪儿》的时候，当时遮遮掩掩的林志颖老婆低调探班，总让人觉得格外...
# 1  翩若惊鸿，婉若游龙。曹植形容洛神的这两句，实在太抽象，以至于始终寻不到承受对象。直到在《大军...
# 2  上个世纪香港影视界涌现出了不少高颜值女星，在《大话西游之月光宝盒》中饰演春三十娘和蜘蛛精的蓝...
# 3  霍建华林心如1905电影网讯近日，林心如在接受采访时爆料称老公霍建华会主动向女儿索吻，笑称他...
# 4  不知道有多少人是看TVB剧集长大的，小时候我每一天晚上都会守着电视看TVB剧集的。可以说对于...
#
#                       title_list  \
# 0  [林志颖, 老婆, 深夜, 面膜, 睫毛, 太长, 吓人]
# 1          [杨幂, 身材, 杨幂, 回复, 太精彩]
# 2            [年轻, 风华绝代, 无人, 送祝福]
# 3     [林心如, 曝霍, 建华, 私生活, 老公, 人气]
# 4     [TVB, 颜值, 担当, 照曝光, 发现, 真老]
#
#                                            text_list  \
# 0  [早年, 林志颖, kimi, 爸爸, 当时, 遮遮掩掩, 林志颖, 老婆, 低调, 探班,...
# 1  [翩若惊鸿, 婉若游龙, 曹植, 形容, 洛神, 两句, 实在太, 抽象, 始终, 不到, ...
# 2  [上个世纪, 香港, 影视界, 涌现出, 不少, 颜值, 女星, 大话西游, 月光宝盒, 饰...
# 3  [建华, 林心如, 1905, 电影, 网讯, 近日, 林心如, 接受, 采访, 爆料, 老...
# 4  [知道, TVB, 剧集, 长大, 小时候, 一天, 晚上, 电视, TVB, 剧集, 时期...
#
#                                           title_text  \
# 0  林志颖老婆深夜敷面膜，睫毛太长好吓人。早年林志颖带kimi上《爸爸去哪儿》的时候，当时遮遮掩...
# 1  小s夸杨幂身材好，杨幂回复太精彩了！。翩若惊鸿，婉若游龙。曹植形容洛神的这两句，实在太抽象，...
# 2  年轻时的她风华绝代，现却无人送祝福。上个世纪香港影视界涌现出了不少高颜值女星，在《大话西游之...
# 3  林心如屡曝霍建华私生活被怼蹭老公人气。霍建华林心如1905电影网讯近日，林心如在接受采访时爆...
# 4  曾是TVB颜值担当，近照曝光发现真老了。不知道有多少人是看TVB剧集长大的，小时候我每一天晚...
#
#                                      title_text_list  \
# 0  [林志颖, 老婆, 深夜, 面膜, 睫毛, 太长, 吓人, 早年, 林志颖, kimi, 爸...
# 1  [杨幂, 身材, 杨幂, 回复, 太精彩, 翩若惊鸿, 婉若游龙, 曹植, 形容, 洛神, ...
# 2  [年轻, 风华绝代, 无人, 送祝福, 上个世纪, 香港, 影视界, 涌现出, 不少, 颜值...
# 3  [林心如, 曝霍, 建华, 私生活, 老公, 人气, 建华, 林心如, 1905, 电影, ...
# 4  [TVB, 颜值, 担当, 照曝光, 发现, 真老, 知道, TVB, 剧集, 长大, 小时...
#
#                                          result_dict
# 0  {'陈若仪': 0.3694296370148557, '睫毛': 0.1351004585...
# 1  {'张钧甯': 0.3084016205516576, '洛神': 0.2855570782...
# 2  {'蓝洁瑛': 0.5638080031961631, '风华绝代': 0.10505389...
# 3  {'建华': 0.7487552626390268, '林心如': 0.7431328710...
# 4  {'姚莹莹': 0.20642930082029642, 'TVB': 0.09534879...

# %%
keyword_set = set()
for keyword_list in train_doc_keyword_df['keyword_list']:
    for keyword in keyword_list:
        keyword_set.add(keyword)

def get_deal_result_list(keyword_set, sample_df):
    temp_df = pd.DataFrame(columns=['id', 'result_list'])
    for temp_id, title_list, result_dict in sample_df[['id', 'title_list', 'result_dict']].values:
        title_set = set(title_list)
        keys = list(result_dict.keys())
        result_list = list()
        result_list_1 = list()
        result_list_2 = list()
        result_list_3 = list()
        result_list_4 = list()
        for title in title_set:
            if len(title) >= 5:
                result_list.append(title)
        for key in keys:
            if key in set(result_list):
                continue
            if((key in keyword_set) & (key in title_set)):
                result_list_1.append(key)
            else:
                if key in keyword_set:
                    result_list_2.append(key)
                else:
                    if key in title_set:
                        result_list_3.append(key)
                    else:
                        result_list_4.append(key)
        result_list = result_list + result_list_1 + result_list_3 + result_list_2 + result_list_4
        temp = pd.DataFrame([[temp_id, result_list]], columns=['id', 'result_list'])
        temp_df = pd.concat([temp_df, temp])
    print(temp_df.head())
    sample_df = pd.merge(sample_df, temp_df, on='id', how='left')
    return sample_df

def get_top_n_word(result_list, n):
    if len(result_list) < n:
        return '无'
    else:
        return result_list[n - 1]
    
sample_df = get_deal_result_list(keyword_set, sample_df)
sample_df['label1'] = sample_df['result_list'].map(lambda x: get_top_n_word(x, 1))
sample_df['label2'] = sample_df['result_list'].map(lambda x: get_top_n_word(x, 2))
print(sample_df.head())
# Out:
#         id                 result_list
# 0  D000001      [睫毛, 面膜, 林志颖, 陈若仪, 日常]
# 0  D000002    [张钧甯, 洛神, 姿艳逸, 外朗, 仪静体闲]
# 0  D000003  [风华绝代, 送祝福, 生日, 蓝洁瑛, 妩媚动人]
# 0  D000004       [建华, 林心如, 粉丝, 女儿, 索吻]
# 0  D000005      [TVB, 素颜, 姚莹莹, 药房, 剧集]
#         id label1 label2                title  \
# 0  D000001     睫毛     面膜   林志颖老婆深夜敷面膜，睫毛太长好吓人
# 1  D000002    张钧甯     洛神   小s夸杨幂身材好，杨幂回复太精彩了！
# 2  D000003   风华绝代    送祝福    年轻时的她风华绝代，现却无人送祝福
# 3  D000004     建华    林心如   林心如屡曝霍建华私生活被怼蹭老公人气
# 4  D000005    TVB     素颜  曾是TVB颜值担当，近照曝光发现真老了
#
#                                                 text  \
# 0  早年林志颖带kimi上《爸爸去哪儿》的时候，当时遮遮掩掩的林志颖老婆低调探班，总让人觉得格外...
# 1  翩若惊鸿，婉若游龙。曹植形容洛神的这两句，实在太抽象，以至于始终寻不到承受对象。直到在《大军...
# 2  上个世纪香港影视界涌现出了不少高颜值女星，在《大话西游之月光宝盒》中饰演春三十娘和蜘蛛精的蓝...
# 3  霍建华林心如1905电影网讯近日，林心如在接受采访时爆料称老公霍建华会主动向女儿索吻，笑称他...
# 4  不知道有多少人是看TVB剧集长大的，小时候我每一天晚上都会守着电视看TVB剧集的。可以说对于...
#
#                       title_list  \
# 0  [林志颖, 老婆, 深夜, 面膜, 睫毛, 太长, 吓人]
# 1          [杨幂, 身材, 杨幂, 回复, 太精彩]
# 2            [年轻, 风华绝代, 无人, 送祝福]
# 3     [林心如, 曝霍, 建华, 私生活, 老公, 人气]
# 4     [TVB, 颜值, 担当, 照曝光, 发现, 真老]
#
#                                            text_list  \
# 0  [早年, 林志颖, kimi, 爸爸, 当时, 遮遮掩掩, 林志颖, 老婆, 低调, 探班,...
# 1  [翩若惊鸿, 婉若游龙, 曹植, 形容, 洛神, 两句, 实在太, 抽象, 始终, 不到, ...
# 2  [上个世纪, 香港, 影视界, 涌现出, 不少, 颜值, 女星, 大话西游, 月光宝盒, 饰...
# 3  [建华, 林心如, 1905, 电影, 网讯, 近日, 林心如, 接受, 采访, 爆料, 老...
# 4  [知道, TVB, 剧集, 长大, 小时候, 一天, 晚上, 电视, TVB, 剧集, 时期...
#
#                                           title_text  \
# 0  林志颖老婆深夜敷面膜，睫毛太长好吓人。早年林志颖带kimi上《爸爸去哪儿》的时候，当时遮遮掩...
# 1  小s夸杨幂身材好，杨幂回复太精彩了！。翩若惊鸿，婉若游龙。曹植形容洛神的这两句，实在太抽象，...
# 2  年轻时的她风华绝代，现却无人送祝福。上个世纪香港影视界涌现出了不少高颜值女星，在《大话西游之...
# 3  林心如屡曝霍建华私生活被怼蹭老公人气。霍建华林心如1905电影网讯近日，林心如在接受采访时爆...
# 4  曾是TVB颜值担当，近照曝光发现真老了。不知道有多少人是看TVB剧集长大的，小时候我每一天晚...
#
#                                      title_text_list  \
# 0  [林志颖, 老婆, 深夜, 面膜, 睫毛, 太长, 吓人, 早年, 林志颖, kimi, 爸...
# 1  [杨幂, 身材, 杨幂, 回复, 太精彩, 翩若惊鸿, 婉若游龙, 曹植, 形容, 洛神, ...
# 2  [年轻, 风华绝代, 无人, 送祝福, 上个世纪, 香港, 影视界, 涌现出, 不少, 颜值...
# 3  [林心如, 曝霍, 建华, 私生活, 老公, 人气, 建华, 林心如, 1905, 电影, ...
# 4  [TVB, 颜值, 担当, 照曝光, 发现, 真老, 知道, TVB, 剧集, 长大, 小时...
#
#                                          result_dict  \
# 0  {'陈若仪': 0.3694296370148557, '睫毛': 0.1351004585...
# 1  {'张钧甯': 0.3084016205516576, '洛神': 0.2855570782...
# 2  {'蓝洁瑛': 0.5638080031961631, '风华绝代': 0.10505389...
# 3  {'建华': 0.7487552626390268, '林心如': 0.7431328710...
# 4  {'姚莹莹': 0.20642930082029642, 'TVB': 0.09534879...
#
#                   result_list
# 0      [睫毛, 面膜, 林志颖, 陈若仪, 日常]
# 1    [张钧甯, 洛神, 姿艳逸, 外朗, 仪静体闲]
# 2  [风华绝代, 送祝福, 生日, 蓝洁瑛, 妩媚动人]
# 3       [建华, 林心如, 粉丝, 女儿, 索吻]
# 4      [TVB, 素颜, 姚莹莹, 药房, 剧集]

# %%
print(sample_df[['id', 'result_list', 'title_list']].head(50))
# Out:
#          id                             result_list  \
# 0   D000001                  [睫毛, 面膜, 林志颖, 陈若仪, 日常]
# 1   D000002                [张钧甯, 洛神, 姿艳逸, 外朗, 仪静体闲]
# 2   D000003              [风华绝代, 送祝福, 生日, 蓝洁瑛, 妩媚动人]
# 3   D000004                   [建华, 林心如, 粉丝, 女儿, 索吻]
# 4   D000005                  [TVB, 素颜, 姚莹莹, 药房, 剧集]
# 5   D000006                   [范冰冰, 公主, 塞娅, 惊艳, 赵薇]
# 6   D000007               [周冬雨, 周迅, 后来的我们, 如果爱, 老孙]
# 7   D000008                    [谢娜, 张杰, 自嘲, 何炅, 劈柴]
# 8   D000009                  [杨幂, 大幂, 主编, 托腮卖萌, 张宇]
# 9   D000010                  [杨幂, 女扮男装, 十岁, 大幂, 帽子]
# 10  D000011                   [吴彦祖, 蒋怡, 篮球, 球例, 狄森]
# 11  D000012                   [甄嬛, 婚纱照, 眉庄, 剧外, 好大]
# 12  D000013                 [林志玲, 人比花, 花美人, 壁花, 还配]
# 13  D000014                 [主持人, 何炅, 节目, 主持, 综艺节目]
# 14  D000015                    [春阳, 沈阳, 妻子, 溜达, 阳洋]
# 15  D000016                   [陈冠希, 女儿, 滚君, 父亲, 锋芒]
# 16  D000017                 [张艺谋, 太太, 陈婷, 张伟平, 周晓枫]
# 17  D000018                  [超模, 刘雯, 秦舒培, 模特, 孙菲菲]
# 18  D000019                [祝绪丹, 饰演, 紫明宫, 白浅大闹, 很圈]
# 19  D000020                 [漫画, 漫威, 超级英雄, 古德曼, 斯坦]
# 20  D000021         [后来的我们, 成龙, 吴卓林, Andi, 女友, 小龙女]
# 21  D000022                  [萌妻食神, 刘婷, 小军, 韩露, 郑恺]
# 22  D000023                  [撞脸, 王珞丹, 杨洋, 李沁, 邢昭林]
# 23  D000024                   [虐心, 正圆, 二少爷, 周莹, 剧情]
# 24  D000025                  [张小斐, 贾玲, 干女儿, 冯巩, 很静]
# 25  D000026                   [女主, 黑风, 大当家, 男主, 甜宠]
# 26  D000027                   [裙子, 鞠婧, 惹吐槽, 整容, 估计]
# 27  D000028                   [爱情, 铁木真, 忽出, 以爱, 冥王]
# 28  D000029                  [张翰, 湖南卫视, 十年, 平凡, 感恩]
# 29  D000030                   [谭松韵, 笑容, 新垣, 结衣, 治愈]
# 30  D000031               [周杰伦, 刘嘉玲, 梁朝伟, 张学友, 梁家辉]
# 31  D000032              [立陶宛, 米纳斯, 伯格曼, VMT, 假面舞会]
# 32  D000033             [后来的我们, 导演, 我怕, 可悲, 肖洋, 爱上]
# 33  D000034                   [女儿国, 唐僧, 青蛇, 白蛇, 法海]
# 34  D000035                [吴奇隆, 有多帅, 吴彦祖, 纯天然, 黎明]
# 35  D000036                   [黄蜂, 中蚁, 幽灵, 霍普去, 营救]
# 36  D000037                   [婚姻, 别离, 一站, 契约, 李小冉]
# 37  D000038               [陈冠希, 女儿, 女星, alaia, 责任心]
# 38  D000039                 [长发, 俞灏明, 韩庚, 周渝民, 谢霆锋]
# 39  D000040            [后来的我们, 小晓, 林见清, 电影, 前任, 女优]
# 40  D000041                   [七个, 定档, 手机, 陌生人, 度及]
# 41  D000042                    [张翰, 魏晨, 闹翻, 反恐, 叶烁]
# 42  D000043               [韩国, 港台明星, 张国荣, 王祖贤, 袁洁莹]
# 43  D000044  [后来的我们, Kyson, 陈若仪, Jesnson, 动物园, 双子星]
# 44  D000045                 [周冬雨, 飞机场, 娱乐圈, 舆论, 胸小]
# 45  D000046        [无限战争, 票房, 复仇者联盟, 康姆斯科, 亿美元, 周末]
# 46  D000047                  [周杰伦, 抢镜, 妈妈, 身后, 叶惠美]
# 47  D000048                    [金星, 激素, 女人, 越活, 走红]
# 48  D000049                   [科技, 古城墙, 吴艳, 光影, 城墙]
# 49  D000050              [萌妻食神, 叶佳瑶, 种丹妮, 柳梦甜, 徐志贤]
#
#                                         title_list
# 0                    [林志颖, 老婆, 深夜, 面膜, 睫毛, 太长, 吓人]
# 1                            [杨幂, 身材, 杨幂, 回复, 太精彩]
# 2                              [年轻, 风华绝代, 无人, 送祝福]
# 3                       [林心如, 曝霍, 建华, 私生活, 老公, 人气]
# 4                       [TVB, 颜值, 担当, 照曝光, 发现, 真老]
# 5                    [16, 范冰冰, 多美, 塞娅, 公主, 一眼, 惊艳]
# 6                                    [北京, 周迅, 周冬雨]
# 7                         [张杰, 自嘲, 废物, 谢娜, 时代, 女性]
# 8                    [杨幂, 杂志, 主编, 夸奖, 大幂, 越来越, 漂亮]
# 9                   [杨幂, 女扮男装, 现身, 节目, 瞬间, 年轻, 十岁]
# 10                   [搭戏, 吴彦祖, 出名, 如今, 40, 迎来, 二胎]
# 11                     [尴尬, 俞灏明, 音乐节, 卫生间, 突然, 拉开]
# 12                      [仙女, 本人, 43, 林志玲, 自拍, 人比花]
# 13                 [主持人, 霸屏, 哪般, 提升, 能力, 与时俱进, 关键]
# 14                        [沈阳, 妻子, 外出, 散步, 春阳, 素颜]
# 15                                           [陈冠希]
# 16                [张艺谋, 太太, 首度, 受访, 说出, 老谋子, 爱情故事]
# 17   [中国, 十大, 国际, 超模, 排行榜, 出炉, 第一名, 意料之中, 第二名, 争议]
# 18            [两人, 出演, 三生三世, 如今, 一人, 片约, 不断, 销声匿迹]
# 19              [漫威, 漫画, 发展史, 发行, 一部, 电影, 具有, 说服力]
# 20         [后来的我们, 票房, 10, 登上, 华语, 影史, 最最, 最最, 导演]
# 21             [虐狗, 神剧, 萌妻食神, 开播, 收视率, 轻松, 郑凯, 原因]
# 22               [撞衫, 可怕, 撞脸, 尴尬, 看看, 娱乐圈, 撞脸, 明星]
# 23               [回顾, 电视剧, 那年, 花开, 正圆, 结局, 虐心, 有喜]
# 24           [不要, 出名, 冲昏, 头脑, 娱乐, 名媛, 张小斐, 谨慎, 前行]
# 25                                 [萌妻食神, 甜而不, 种田]
# 26                   [鞠婧, 裙子, 短到, 不敢, 大步, 走路, 惹吐槽]
# 27                                    [战神, 爱情, 对错]
# 28          [张翰, 出道, 十年, 重回, 湖南卫视, 回忆, 演艺, 生涯, 感慨]
# 29              [27, 谭松韵, 能演, 17, 娱乐圈, 第一, 元气, 女神]
# 30  [地表, 最强, 应援, 周杰伦, 刘嘉玲, 梁朝伟, 张家辉, 邱淑贞, 组团, 演唱会]
# 31  [静安, 戏剧, 汇集, 外国, 名团, 立陶宛, 国宝级, 导演, 带来, 三部, 力作]
# 32                   [后来的我们, 小晓, 扮演者, 周冬雨, 主演, 电影]
# 33          [电影, 电视剧, 长大, 原来, 唐僧, 真的, 喜欢, 女儿国, 国王]
# 34            [吴彦祖, 黎明, 吴奇隆, 颜值, 巅峰, 有多帅, 年代, 纯天然]
# 35           [娱乐圈, 明星, 胡歌, 像养, 女友, 鹿晗, 眼神, 宠溺, 网友]
# 36                  [一站, 别离, 李小冉, 演绎, 契约, 婚姻, 轻喜剧]
# 37                           [陈冠希, 男人, 男人, 转变, 过程]
# 38         [男星, 长发, 韩庚, 马特, 俞灏明, 玛丽, 易烊千玺, 颠覆, 形象]
# 39                       [后来的我们, 无病呻吟, 有点, 过时, 土气]
# 40                       [七个, 好友, 部手机, 不止, 七个, 秘密]
# 41                  [张翰, 魏晨, 闹翻, 两人, 久未联系, 关系, 未变]
# 42           [九十年代, 港台明星, 韩国, 很火, 人人, 喜欢, 张国荣, 希望]
# 43             [生活, 真实, 超越, 电影, 后来的我们, 没有, 告诉, 真理]
# 44              [飞机场, 女王, 周冬雨, 简单, 做作, 这才, 美的, 样子]
# 45                       [漫威, 复仇者联盟, 无限战争, 票房, 历史]
# 46                       [周杰伦, 妈妈, 撞衫, 身后, 女人, 抢镜]
# 47          [金星, 照曝光, 男人, 味十足, 网友, 停用, 激素, 反差, 太大]
# 48                                   [科技, 古城墙, 夜空]
# 49             [萌妻食神, 叶佳瑶, 金句, 合集, 情话, 太甜, 剧超, 好看]

# %%
# 导出预测结果
def exportResult(df, fileName):
    df.to_csv('../../result/chusai/%s.csv' % fileName, header=True, index=False)
    
exportResult(sample_df[['id', 'label1', 'label2']], 'tfidf_9_5_4')
